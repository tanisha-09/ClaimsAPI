# %%
import pandas as pd
import seaborn as sns
import re
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# %%
train_indf=pd.read_csv('Health Claims/Train_Inpatientdata.csv')
train_outdf=pd.read_csv('Health Claims/Train_Outpatientdata.csv')
train_ben=pd.read_csv('Health Claims/Train_Beneficiarydata.csv')

test_indf=pd.read_csv('Health Claims/Test_Inpatientdata.csv')
test_outdf=pd.read_csv('Health Claims/Test_Outpatientdata.csv')
test_ben=pd.read_csv('Health Claims/Test_Beneficiarydata.csv')

# %%
train = pd.concat([train_indf, train_outdf])
test = pd.concat([test_indf, test_outdf])

# %%
train_ben.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138556 entries, 0 to 138555
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           138556 non-null  object
#  1   DOB                              138556 non-null  object
#  2   DOD                              1421 non-null    object
#  3   Gender                           138556 non-null  int64
#  4   Race                             138556 non-null  int64
#  5   RenalDiseaseIndicator            138556 non-null  object
#  6   State                            138556 non-null  int64
#  7   County                           138556 non-null  int64
#  8   NoOfMonths_PartACov              138556 non-null  int64
#  9   NoOfMonths_PartBCov              138556 non-null  int64
#  10  ChronicCond_Alzheimer            138556 non-null  int64
#  11  ChronicCond_Heartfailure         138556 non-null  int64
#  12  ChronicCond_KidneyDisease        138556 non-null  int64
#  13  ChronicCond_Cancer               138556 non-null  int64
#  14  ChronicCond_ObstrPulmonary       138556 non-null  int64
#  15  ChronicCond_Depression           138556 non-null  int64
#  16  ChronicCond_Diabetes             138556 non-null  int64
#  17  ChronicCond_IschemicHeart        138556 non-null  int64
#  18  ChronicCond_Osteoporasis         138556 non-null  int64
#  19  ChronicCond_rheumatoidarthritis  138556 non-null  int64
#  20  ChronicCond_stroke               138556 non-null  int64
#  21  IPAnnualReimbursementAmt         138556 non-null  int64
#  22  IPAnnualDeductibleAmt            138556 non-null  int64
#  23  OPAnnualReimbursementAmt         138556 non-null  int64
#  24  OPAnnualDeductibleAmt            138556 non-null  int64
# dtypes: int64(21), object(4)
# memory usage: 26.4+ MB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 558211 entries, 0 to 517736
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   BeneID                  558211 non-null  object
#  1   ClaimID                 558211 non-null  object
#  2   ClaimStartDt            558211 non-null  object
#  3   ClaimEndDt              558211 non-null  object
#  4   Provider                558211 non-null  object
#  5   InscClaimAmtReimbursed  558211 non-null  int64
#  6   AttendingPhysician      556703 non-null  object
#  7   OperatingPhysician      114447 non-null  object
#  8   OtherPhysician          199736 non-null  object
#  9   AdmissionDt             40474 non-null   object
#  10  ClmAdmitDiagnosisCode   145899 non-null  object
#  11  DeductibleAmtPaid       557312 non-null  float64
#  12  DischargeDt             40474 non-null   object
#  13  DiagnosisGroupCode      40474 non-null   object
#  14  ClmDiagnosisCode_1      547758 non-null  object
#  15  ClmDiagnosisCode_2      362605 non-null  object
#  16  ClmDiagnosisCode_3      243055 non-null  object
#  17  ClmDiagnosisCode_4      164536 non-null  object
#  18  ClmDiagnosisCode_5      111924 non-null  object
#  19  ClmDiagnosisCode_6      84392 non-null   object
#  20  ClmDiagnosisCode_7      66177 non-null   object
#  21  ClmDiagnosisCode_8      53444 non-null   object
#  22  ClmDiagnosisCode_9      41815 non-null   object
#  23  ClmDiagnosisCode_10     5010 non-null    object
#  24  ClmProcedureCode_1      23310 non-null   float64
#  25  ClmProcedureCode_2      5490 non-null    float64
#  26  ClmProcedureCode_3      969 non-null     float64
#  27  ClmProcedureCode_4      118 non-null     float64
#  28  ClmProcedureCode_5      9 non-null       float64
#  29  ClmProcedureCode_6      0 non-null       float64
# dtypes: float64(7), int64(1), object(22)
# memory usage: 132.0+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 135392 entries, 0 to 125840
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   BeneID                  135392 non-null  object
#  1   ClaimID                 135392 non-null  object
#  2   ClaimStartDt            135392 non-null  object
#  3   ClaimEndDt              135392 non-null  object
#  4   Provider                135392 non-null  object
#  5   InscClaimAmtReimbursed  135392 non-null  int64
#  6   AttendingPhysician      135045 non-null  object
#  7   OperatingPhysician      27193 non-null   object
#  8   OtherPhysician          48632 non-null   object
#  9   AdmissionDt             9551 non-null    object
#  10  ClmAdmitDiagnosisCode   35356 non-null   object
#  11  DeductibleAmtPaid       135196 non-null  float64
#  12  DischargeDt             9551 non-null    object
#  13  DiagnosisGroupCode      9551 non-null    object
#  14  ClmDiagnosisCode_1      132814 non-null  object
#  15  ClmDiagnosisCode_2      87607 non-null   object
#  16  ClmDiagnosisCode_3      58648 non-null   object
#  17  ClmDiagnosisCode_4      39617 non-null   object
#  18  ClmDiagnosisCode_5      26798 non-null   object
#  19  ClmDiagnosisCode_6      20160 non-null   object
#  20  ClmDiagnosisCode_7      15785 non-null   object
#  21  ClmDiagnosisCode_8      12722 non-null   object
#  22  ClmDiagnosisCode_9      9876 non-null    object
#  23  ClmDiagnosisCode_10     1150 non-null    object
#  24  ClmProcedureCode_1      5467 non-null    float64
#  25  ClmProcedureCode_2      1263 non-null    float64
#  26  ClmProcedureCode_3      225 non-null     float64
#  27  ClmProcedureCode_4      29 non-null      float64
#  28  ClmProcedureCode_5      2 non-null       float64
#  29  ClmProcedureCode_6      0 non-null       float64
# dtypes: float64(7), int64(1), object(22)
# memory usage: 32.0+ MB

# %%
final_train = pd.merge(train_ben, train, on='BeneID', how='left')

# %%
final_train
# Out:
#             BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  \
# 0        BENE11001  1943-01-01  NaN       1     1                     0
# 1        BENE11001  1943-01-01  NaN       1     1                     0
# 2        BENE11001  1943-01-01  NaN       1     1                     0
# 3        BENE11002  1936-09-01  NaN       2     1                     0
# 4        BENE11003  1936-08-01  NaN       1     1                     0
# ...            ...         ...  ...     ...   ...                   ...
# 558206  BENE159198  1952-04-01  NaN       2     1                     0
# 558207  BENE159198  1952-04-01  NaN       2     1                     0
# 558208  BENE159198  1952-04-01  NaN       2     1                     0
# 558209  BENE159198  1952-04-01  NaN       2     1                     0
# 558210  BENE159198  1952-04-01  NaN       2     1                     0
#
#         State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0          39     230                   12                   12  ...
# 1          39     230                   12                   12  ...
# 2          39     230                   12                   12  ...
# 3          39     280                   12                   12  ...
# 4          52     590                   12                   12  ...
# ...       ...     ...                  ...                  ...  ...
# 558206     21      20                   12                   12  ...
# 558207     21      20                   12                   12  ...
# 558208     21      20                   12                   12  ...
# 558209     21      20                   12                   12  ...
# 558210     21      20                   12                   12  ...
#
#         ClmDiagnosisCode_7  ClmDiagnosisCode_8  ClmDiagnosisCode_9  \
# 0                     2724               19889                5849
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                2724                V103                 NaN
#
#         ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN              7092.0                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 558206                  NaN                 NaN                 NaN
# 558207                  NaN                 NaN                 NaN
# 558208                  NaN                 NaN                 NaN
# 558209                  NaN                 NaN                 NaN
# 558210                  NaN                 NaN                 NaN
#
#         ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_6
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 558206                 NaN
# 558207                 NaN
# 558208                 NaN
# 558209                 NaN
# 558210                 NaN
#
# [558211 rows x 54 columns]

# %%
final_test = pd.merge(test_ben, test, on='BeneID', how='left')

# %%
final_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135392 entries, 0 to 135391
# Data columns (total 54 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           135392 non-null  object
#  1   DOB                              135392 non-null  object
#  2   DOD                              1040 non-null    object
#  3   Gender                           135392 non-null  int64
#  4   Race                             135392 non-null  int64
#  5   RenalDiseaseIndicator            135392 non-null  object
#  6   State                            135392 non-null  int64
#  7   County                           135392 non-null  int64
#  8   NoOfMonths_PartACov              135392 non-null  int64
#  9   NoOfMonths_PartBCov              135392 non-null  int64
#  10  ChronicCond_Alzheimer            135392 non-null  int64
#  11  ChronicCond_Heartfailure         135392 non-null  int64
#  12  ChronicCond_KidneyDisease        135392 non-null  int64
#  13  ChronicCond_Cancer               135392 non-null  int64
#  14  ChronicCond_ObstrPulmonary       135392 non-null  int64
#  15  ChronicCond_Depression           135392 non-null  int64
#  16  ChronicCond_Diabetes             135392 non-null  int64
#  17  ChronicCond_IschemicHeart        135392 non-null  int64
#  18  ChronicCond_Osteoporasis         135392 non-null  int64
#  19  ChronicCond_rheumatoidarthritis  135392 non-null  int64
#  20  ChronicCond_stroke               135392 non-null  int64
#  21  IPAnnualReimbursementAmt         135392 non-null  int64
#  22  IPAnnualDeductibleAmt            135392 non-null  int64
#  23  OPAnnualReimbursementAmt         135392 non-null  int64
#  24  OPAnnualDeductibleAmt            135392 non-null  int64
#  25  ClaimID                          135392 non-null  object
#  26  ClaimStartDt                     135392 non-null  object
#  27  ClaimEndDt                       135392 non-null  object
#  28  Provider                         135392 non-null  object
#  29  InscClaimAmtReimbursed           135392 non-null  int64
#  30  AttendingPhysician               135045 non-null  object
#  31  OperatingPhysician               27193 non-null   object
#  32  OtherPhysician                   48632 non-null   object
#  33  AdmissionDt                      9551 non-null    object
#  34  ClmAdmitDiagnosisCode            35356 non-null   object
#  35  DeductibleAmtPaid                135196 non-null  float64
#  36  DischargeDt                      9551 non-null    object
#  37  DiagnosisGroupCode               9551 non-null    object
#  38  ClmDiagnosisCode_1               132814 non-null  object
#  39  ClmDiagnosisCode_2               87607 non-null   object
#  40  ClmDiagnosisCode_3               58648 non-null   object
#  41  ClmDiagnosisCode_4               39617 non-null   object
#  42  ClmDiagnosisCode_5               26798 non-null   object
#  43  ClmDiagnosisCode_6               20160 non-null   object
#  44  ClmDiagnosisCode_7               15785 non-null   object
#  45  ClmDiagnosisCode_8               12722 non-null   object
#  46  ClmDiagnosisCode_9               9876 non-null    object
#  47  ClmDiagnosisCode_10              1150 non-null    object
#  48  ClmProcedureCode_1               5467 non-null    float64
#  49  ClmProcedureCode_2               1263 non-null    float64
#  50  ClmProcedureCode_3               225 non-null     float64
#  51  ClmProcedureCode_4               29 non-null      float64
#  52  ClmProcedureCode_5               2 non-null       float64
#  53  ClmProcedureCode_6               0 non-null       float64
# dtypes: float64(7), int64(22), object(25)
# memory usage: 55.8+ MB

# %%
cols_to_remove=['DOB','DOD','NoOfMonths_PartACov','NoOfMonths_PartBCov']
#'IPAnnualReimbursementAmt','IPAnnualDeductibleAmt','OPAnnualReimbursementAmt','OPAnnualDeductibleAmt'
final_train=final_train.drop(columns=cols_to_remove)
final_test=final_test.drop(columns=cols_to_remove)

# %%
final_train.shape
# Out:
# (558211, 50)

# %%
final_test.shape
# Out:
# (135392, 50)

# %%
final_train['RenalDiseaseIndicator'] = final_train['RenalDiseaseIndicator'].replace({'Y': 1})
final_train['RenalDiseaseIndicator'] = final_train['RenalDiseaseIndicator'].replace({0: 2})
final_train['RenalDiseaseIndicator'] = final_train['RenalDiseaseIndicator'].astype(int)

final_test['RenalDiseaseIndicator'] = final_test['RenalDiseaseIndicator'].replace({'Y': 1})
final_test['RenalDiseaseIndicator'] = final_test['RenalDiseaseIndicator'].replace({0: 2})
final_test['RenalDiseaseIndicator'] = final_test['RenalDiseaseIndicator'].astype(int)
#1 stands for yes and 2 stands for no

# %%
final_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558211 entries, 0 to 558210
# Data columns (total 50 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           558211 non-null  object
#  1   Gender                           558211 non-null  int64
#  2   Race                             558211 non-null  int64
#  3   RenalDiseaseIndicator            558211 non-null  int64
#  4   State                            558211 non-null  int64
#  5   County                           558211 non-null  int64
#  6   ChronicCond_Alzheimer            558211 non-null  int64
#  7   ChronicCond_Heartfailure         558211 non-null  int64
#  8   ChronicCond_KidneyDisease        558211 non-null  int64
#  9   ChronicCond_Cancer               558211 non-null  int64
#  10  ChronicCond_ObstrPulmonary       558211 non-null  int64
#  11  ChronicCond_Depression           558211 non-null  int64
#  12  ChronicCond_Diabetes             558211 non-null  int64
#  13  ChronicCond_IschemicHeart        558211 non-null  int64
#  14  ChronicCond_Osteoporasis         558211 non-null  int64
#  15  ChronicCond_rheumatoidarthritis  558211 non-null  int64
#  16  ChronicCond_stroke               558211 non-null  int64
#  17  IPAnnualReimbursementAmt         558211 non-null  int64
#  18  IPAnnualDeductibleAmt            558211 non-null  int64
#  19  OPAnnualReimbursementAmt         558211 non-null  int64
#  20  OPAnnualDeductibleAmt            558211 non-null  int64
#  21  ClaimID                          558211 non-null  object
#  22  ClaimStartDt                     558211 non-null  object
#  23  ClaimEndDt                       558211 non-null  object
#  24  Provider                         558211 non-null  object
#  25  InscClaimAmtReimbursed           558211 non-null  int64
#  26  AttendingPhysician               556703 non-null  object
#  27  OperatingPhysician               114447 non-null  object
#  28  OtherPhysician                   199736 non-null  object
#  29  AdmissionDt                      40474 non-null   object
#  30  ClmAdmitDiagnosisCode            145899 non-null  object
#  31  DeductibleAmtPaid                557312 non-null  float64
#  32  DischargeDt                      40474 non-null   object
#  33  DiagnosisGroupCode               40474 non-null   object
#  34  ClmDiagnosisCode_1               547758 non-null  object
#  35  ClmDiagnosisCode_2               362605 non-null  object
#  36  ClmDiagnosisCode_3               243055 non-null  object
#  37  ClmDiagnosisCode_4               164536 non-null  object
#  38  ClmDiagnosisCode_5               111924 non-null  object
#  39  ClmDiagnosisCode_6               84392 non-null   object
#  40  ClmDiagnosisCode_7               66177 non-null   object
#  41  ClmDiagnosisCode_8               53444 non-null   object
#  42  ClmDiagnosisCode_9               41815 non-null   object
#  43  ClmDiagnosisCode_10              5010 non-null    object
#  44  ClmProcedureCode_1               23310 non-null   float64
#  45  ClmProcedureCode_2               5490 non-null    float64
#  46  ClmProcedureCode_3               969 non-null     float64
#  47  ClmProcedureCode_4               118 non-null     float64
#  48  ClmProcedureCode_5               9 non-null       float64
#  49  ClmProcedureCode_6               0 non-null       float64
# dtypes: float64(7), int64(21), object(22)
# memory usage: 212.9+ MB

# %%
final_train
# Out:
#             BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0        BENE11001       1     1                      0     39     230
# 1        BENE11001       1     1                      0     39     230
# 2        BENE11001       1     1                      0     39     230
# 3        BENE11002       2     1                      0     39     280
# 4        BENE11003       1     1                      0     52     590
# ...            ...     ...   ...                    ...    ...     ...
# 558206  BENE159198       2     1                      0     21      20
# 558207  BENE159198       2     1                      0     21      20
# 558208  BENE159198       2     1                      0     21      20
# 558209  BENE159198       2     1                      0     21      20
# 558210  BENE159198       2     1                      0     21      20
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         2
# 2                           1                         2
# 3                           2                         2
# 4                           1                         2
# ...                       ...                       ...
# 558206                      1                         1
# 558207                      1                         1
# 558208                      1                         1
# 558209                      1                         1
# 558210                      1                         1
#
#         ChronicCond_KidneyDisease  ChronicCond_Cancer  ...  \
# 0                               1                   2  ...
# 1                               1                   2  ...
# 2                               1                   2  ...
# 3                               2                   2  ...
# 4                               2                   2  ...
# ...                           ...                 ...  ...
# 558206                          2                   2  ...
# 558207                          2                   2  ...
# 558208                          2                   2  ...
# 558209                          2                   2  ...
# 558210                          2                   2  ...
#
#         ClmDiagnosisCode_7  ClmDiagnosisCode_8  ClmDiagnosisCode_9  \
# 0                     2724               19889                5849
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                2724                V103                 NaN
#
#         ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN              7092.0                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 558206                  NaN                 NaN                 NaN
# 558207                  NaN                 NaN                 NaN
# 558208                  NaN                 NaN                 NaN
# 558209                  NaN                 NaN                 NaN
# 558210                  NaN                 NaN                 NaN
#
#         ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_6
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 558206                 NaN
# 558207                 NaN
# 558208                 NaN
# 558209                 NaN
# 558210                 NaN
#
# [558211 rows x 50 columns]

# %%
final_test
# Out:
#             BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0        BENE11001       1     1                      0     39     230
# 1        BENE11001       1     1                      0     39     230
# 2        BENE11007       1     2                      0     45     610
# 3        BENE11007       1     2                      0     45     610
# 4        BENE11007       1     2                      0     45     610
# ...            ...     ...   ...                    ...    ...     ...
# 135387  BENE159193       2     1                      0     36     170
# 135388  BENE159193       2     1                      0     36     170
# 135389  BENE159194       1     1                      0     39     140
# 135390  BENE159196       2     1                      0      6     150
# 135391  BENE159197       1     1                      0     16     560
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         2
# 2                           1                         1
# 3                           1                         1
# 4                           1                         1
# ...                       ...                       ...
# 135387                      2                         2
# 135388                      2                         2
# 135389                      1                         2
# 135390                      2                         1
# 135391                      1                         1
#
#         ChronicCond_KidneyDisease  ChronicCond_Cancer  ...  \
# 0                               1                   2  ...
# 1                               1                   2  ...
# 2                               2                   2  ...
# 3                               2                   2  ...
# 4                               2                   2  ...
# ...                           ...                 ...  ...
# 135387                          2                   2  ...
# 135388                          2                   2  ...
# 135389                          2                   2  ...
# 135390                          1                   1  ...
# 135391                          2                   2  ...
#
#         ClmDiagnosisCode_7  ClmDiagnosisCode_8  ClmDiagnosisCode_9  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 135387                 NaN                 NaN                 NaN
# 135388                 NaN                 NaN                 NaN
# 135389                 NaN                 NaN                 NaN
# 135390               25000               V1251                2720
# 135391                 NaN                 NaN                 NaN
#
#         ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 135387                  NaN                 NaN                 NaN
# 135388                  NaN                 NaN                 NaN
# 135389                  NaN                 NaN                 NaN
# 135390                  NaN                 NaN                 NaN
# 135391                  NaN                 NaN                 NaN
#
#         ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 135387                 NaN                 NaN                 NaN
# 135388                 NaN                 NaN                 NaN
# 135389                 NaN                 NaN                 NaN
# 135390                 NaN                 NaN                 NaN
# 135391                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_6
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 135387                 NaN
# 135388                 NaN
# 135389                 NaN
# 135390                 NaN
# 135391                 NaN
#
# [135392 rows x 50 columns]

# %%
# Define weights for chronic conditions
chronic_condition_weights = {
    'ChronicCond_Alzheimer': 1,
    'ChronicCond_Heartfailure': 1,
    'ChronicCond_KidneyDisease': 1,
    'ChronicCond_Cancer': 1,
    'ChronicCond_ObstrPulmonary': 1,
    'ChronicCond_Depression': 1,
    'ChronicCond_Diabetes': 1,
    'ChronicCond_IschemicHeart': 1,
    'ChronicCond_Osteoporasis': 1,
    'ChronicCond_rheumatoidarthritis': 1,
    'ChronicCond_stroke': 1
}

# Calculate weighted sum for chronic conditions
def calculate_weighted_chronic_conditions(row):
    weighted_sum = 0
    for col, weight in chronic_condition_weights.items():
        weighted_sum += row[col] * weight
    return weighted_sum

# Apply the function to create the weighted column
final_train['ChronicCondScore'] = final_train.apply(calculate_weighted_chronic_conditions, axis=1)
final_test['ChronicCondScore'] = final_test.apply(calculate_weighted_chronic_conditions, axis=1)

# %%
final_train
# Out:
#             BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0        BENE11001       1     1                      0     39     230
# 1        BENE11001       1     1                      0     39     230
# 2        BENE11001       1     1                      0     39     230
# 3        BENE11002       2     1                      0     39     280
# 4        BENE11003       1     1                      0     52     590
# ...            ...     ...   ...                    ...    ...     ...
# 558206  BENE159198       2     1                      0     21      20
# 558207  BENE159198       2     1                      0     21      20
# 558208  BENE159198       2     1                      0     21      20
# 558209  BENE159198       2     1                      0     21      20
# 558210  BENE159198       2     1                      0     21      20
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         2
# 2                           1                         2
# 3                           2                         2
# 4                           1                         2
# ...                       ...                       ...
# 558206                      1                         1
# 558207                      1                         1
# 558208                      1                         1
# 558209                      1                         1
# 558210                      1                         1
#
#         ChronicCond_KidneyDisease  ChronicCond_Cancer  ...  \
# 0                               1                   2  ...
# 1                               1                   2  ...
# 2                               1                   2  ...
# 3                               2                   2  ...
# 4                               2                   2  ...
# ...                           ...                 ...  ...
# 558206                          2                   2  ...
# 558207                          2                   2  ...
# 558208                          2                   2  ...
# 558209                          2                   2  ...
# 558210                          2                   2  ...
#
#         ClmDiagnosisCode_8  ClmDiagnosisCode_9  ClmDiagnosisCode_10  \
# 0                    19889                5849                  NaN
# 1                      NaN                 NaN                  NaN
# 2                      NaN                 NaN                  NaN
# 3                      NaN                 NaN                  NaN
# 4                      NaN                 NaN                  NaN
# ...                    ...                 ...                  ...
# 558206                 NaN                 NaN                  NaN
# 558207                 NaN                 NaN                  NaN
# 558208                 NaN                 NaN                  NaN
# 558209                 NaN                 NaN                  NaN
# 558210                V103                 NaN                  NaN
#
#         ClmProcedureCode_1  ClmProcedureCode_2  ClmProcedureCode_3  \
# 0                      NaN                 NaN                 NaN
# 1                   7092.0                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_4  ClmProcedureCode_5  ClmProcedureCode_6  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ChronicCondScore
# 0                     15
# 1                     15
# 2                     15
# 3                     22
# 4                     20
# ...                  ...
# 558206                17
# 558207                17
# 558208                17
# 558209                17
# 558210                17
#
# [558211 rows x 51 columns]

# %%
final_test
# Out:
#             BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0        BENE11001       1     1                      0     39     230
# 1        BENE11001       1     1                      0     39     230
# 2        BENE11007       1     2                      0     45     610
# 3        BENE11007       1     2                      0     45     610
# 4        BENE11007       1     2                      0     45     610
# ...            ...     ...   ...                    ...    ...     ...
# 135387  BENE159193       2     1                      0     36     170
# 135388  BENE159193       2     1                      0     36     170
# 135389  BENE159194       1     1                      0     39     140
# 135390  BENE159196       2     1                      0      6     150
# 135391  BENE159197       1     1                      0     16     560
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         2
# 2                           1                         1
# 3                           1                         1
# 4                           1                         1
# ...                       ...                       ...
# 135387                      2                         2
# 135388                      2                         2
# 135389                      1                         2
# 135390                      2                         1
# 135391                      1                         1
#
#         ChronicCond_KidneyDisease  ChronicCond_Cancer  ...  \
# 0                               1                   2  ...
# 1                               1                   2  ...
# 2                               2                   2  ...
# 3                               2                   2  ...
# 4                               2                   2  ...
# ...                           ...                 ...  ...
# 135387                          2                   2  ...
# 135388                          2                   2  ...
# 135389                          2                   2  ...
# 135390                          1                   1  ...
# 135391                          2                   2  ...
#
#         ClmDiagnosisCode_8  ClmDiagnosisCode_9  ClmDiagnosisCode_10  \
# 0                      NaN                 NaN                  NaN
# 1                      NaN                 NaN                  NaN
# 2                      NaN                 NaN                  NaN
# 3                      NaN                 NaN                  NaN
# 4                      NaN                 NaN                  NaN
# ...                    ...                 ...                  ...
# 135387                 NaN                 NaN                  NaN
# 135388                 NaN                 NaN                  NaN
# 135389                 NaN                 NaN                  NaN
# 135390               V1251                2720                  NaN
# 135391                 NaN                 NaN                  NaN
#
#         ClmProcedureCode_1  ClmProcedureCode_2  ClmProcedureCode_3  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 135387                 NaN                 NaN                 NaN
# 135388                 NaN                 NaN                 NaN
# 135389                 NaN                 NaN                 NaN
# 135390                 NaN                 NaN                 NaN
# 135391                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_4  ClmProcedureCode_5  ClmProcedureCode_6  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 135387                 NaN                 NaN                 NaN
# 135388                 NaN                 NaN                 NaN
# 135389                 NaN                 NaN                 NaN
# 135390                 NaN                 NaN                 NaN
# 135391                 NaN                 NaN                 NaN
#
#         ChronicCondScore
# 0                     15
# 1                     15
# 2                     17
# 3                     17
# 4                     17
# ...                  ...
# 135387                22
# 135388                22
# 135389                21
# 135390                16
# 135391                19
#
# [135392 rows x 51 columns]

# %%
final_train.isnull().sum()
# Out:
# BeneID                                  0
# Gender                                  0
# Race                                    0
# RenalDiseaseIndicator                   0
# State                                   0
# County                                  0
# ChronicCond_Alzheimer                   0
# ChronicCond_Heartfailure                0
# ChronicCond_KidneyDisease               0
# ChronicCond_Cancer                      0
# ChronicCond_ObstrPulmonary              0
# ChronicCond_Depression                  0
# ChronicCond_Diabetes                    0
# ChronicCond_IschemicHeart               0
# ChronicCond_Osteoporasis                0
# ChronicCond_rheumatoidarthritis         0
# ChronicCond_stroke                      0
# IPAnnualReimbursementAmt                0
# IPAnnualDeductibleAmt                   0
# OPAnnualReimbursementAmt                0
# OPAnnualDeductibleAmt                   0
# ClaimID                                 0
# ClaimStartDt                            0
# ClaimEndDt                              0
# Provider                                0
# InscClaimAmtReimbursed                  0
# AttendingPhysician                   1508
# OperatingPhysician                 443764
# OtherPhysician                     358475
# AdmissionDt                        517737
# ClmAdmitDiagnosisCode              412312
# DeductibleAmtPaid                     899
# DischargeDt                        517737
# DiagnosisGroupCode                 517737
# ClmDiagnosisCode_1                  10453
# ClmDiagnosisCode_2                 195606
# ClmDiagnosisCode_3                 315156
# ClmDiagnosisCode_4                 393675
# ClmDiagnosisCode_5                 446287
# ClmDiagnosisCode_6                 473819
# ClmDiagnosisCode_7                 492034
# ClmDiagnosisCode_8                 504767
# ClmDiagnosisCode_9                 516396
# ClmDiagnosisCode_10                553201
# ClmProcedureCode_1                 534901
# ClmProcedureCode_2                 552721
# ClmProcedureCode_3                 557242
# ClmProcedureCode_4                 558093
# ClmProcedureCode_5                 558202
# ClmProcedureCode_6                 558211
# ChronicCondScore                        0
# dtype: int64

# %%
final_test.isnull().sum()
# Out:
# BeneID                                  0
# Gender                                  0
# Race                                    0
# RenalDiseaseIndicator                   0
# State                                   0
# County                                  0
# ChronicCond_Alzheimer                   0
# ChronicCond_Heartfailure                0
# ChronicCond_KidneyDisease               0
# ChronicCond_Cancer                      0
# ChronicCond_ObstrPulmonary              0
# ChronicCond_Depression                  0
# ChronicCond_Diabetes                    0
# ChronicCond_IschemicHeart               0
# ChronicCond_Osteoporasis                0
# ChronicCond_rheumatoidarthritis         0
# ChronicCond_stroke                      0
# IPAnnualReimbursementAmt                0
# IPAnnualDeductibleAmt                   0
# OPAnnualReimbursementAmt                0
# OPAnnualDeductibleAmt                   0
# ClaimID                                 0
# ClaimStartDt                            0
# ClaimEndDt                              0
# Provider                                0
# InscClaimAmtReimbursed                  0
# AttendingPhysician                    347
# OperatingPhysician                 108199
# OtherPhysician                      86760
# AdmissionDt                        125841
# ClmAdmitDiagnosisCode              100036
# DeductibleAmtPaid                     196
# DischargeDt                        125841
# DiagnosisGroupCode                 125841
# ClmDiagnosisCode_1                   2578
# ClmDiagnosisCode_2                  47785
# ClmDiagnosisCode_3                  76744
# ClmDiagnosisCode_4                  95775
# ClmDiagnosisCode_5                 108594
# ClmDiagnosisCode_6                 115232
# ClmDiagnosisCode_7                 119607
# ClmDiagnosisCode_8                 122670
# ClmDiagnosisCode_9                 125516
# ClmDiagnosisCode_10                134242
# ClmProcedureCode_1                 129925
# ClmProcedureCode_2                 134129
# ClmProcedureCode_3                 135167
# ClmProcedureCode_4                 135363
# ClmProcedureCode_5                 135390
# ClmProcedureCode_6                 135392
# ChronicCondScore                        0
# dtype: int64

# %%
final_train.shape
# Out:
# (558211, 51)

# %%
final_test.shape
# Out:
# (135392, 51)

# %%
final_train = final_train.dropna(subset=['AttendingPhysician'])
final_test = final_test.dropna(subset=['AttendingPhysician'])

# %%
columns_to_fill = ['ClmAdmitDiagnosisCode', 'DiagnosisGroupCode','DeductibleAmtPaid']

final_train[columns_to_fill] = final_train[columns_to_fill].fillna(0)
final_test[columns_to_fill] = final_test[columns_to_fill].fillna(0)
# Out:
# /tmp/ipykernel_108008/4088525854.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_train[columns_to_fill] = final_train[columns_to_fill].fillna(0)
# /tmp/ipykernel_108008/4088525854.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_test[columns_to_fill] = final_test[columns_to_fill].fillna(0)

# %%
final_train.shape
# Out:
# (556703, 51)

# %%
final_train.isnull().sum()
# Out:
# BeneID                                  0
# Gender                                  0
# Race                                    0
# RenalDiseaseIndicator                   0
# State                                   0
# County                                  0
# ChronicCond_Alzheimer                   0
# ChronicCond_Heartfailure                0
# ChronicCond_KidneyDisease               0
# ChronicCond_Cancer                      0
# ChronicCond_ObstrPulmonary              0
# ChronicCond_Depression                  0
# ChronicCond_Diabetes                    0
# ChronicCond_IschemicHeart               0
# ChronicCond_Osteoporasis                0
# ChronicCond_rheumatoidarthritis         0
# ChronicCond_stroke                      0
# IPAnnualReimbursementAmt                0
# IPAnnualDeductibleAmt                   0
# OPAnnualReimbursementAmt                0
# OPAnnualDeductibleAmt                   0
# ClaimID                                 0
# ClaimStartDt                            0
# ClaimEndDt                              0
# Provider                                0
# InscClaimAmtReimbursed                  0
# AttendingPhysician                      0
# OperatingPhysician                 442270
# OtherPhysician                     356980
# AdmissionDt                        516341
# ClmAdmitDiagnosisCode                   0
# DeductibleAmtPaid                       0
# DischargeDt                        516341
# DiagnosisGroupCode                      0
# ClmDiagnosisCode_1                  10416
# ClmDiagnosisCode_2                 195028
# ClmDiagnosisCode_3                 314265
# ClmDiagnosisCode_4                 392592
# ClmDiagnosisCode_5                 445053
# ClmDiagnosisCode_6                 472511
# ClmDiagnosisCode_7                 490684
# ClmDiagnosisCode_8                 503387
# ClmDiagnosisCode_9                 514975
# ClmDiagnosisCode_10                551694
# ClmProcedureCode_1                 533447
# ClmProcedureCode_2                 551223
# ClmProcedureCode_3                 555735
# ClmProcedureCode_4                 556585
# ClmProcedureCode_5                 556694
# ClmProcedureCode_6                 556703
# ChronicCondScore                        0
# dtype: int64

# %%
final_test.isnull().sum()
# Out:
# BeneID                                  0
# Gender                                  0
# Race                                    0
# RenalDiseaseIndicator                   0
# State                                   0
# County                                  0
# ChronicCond_Alzheimer                   0
# ChronicCond_Heartfailure                0
# ChronicCond_KidneyDisease               0
# ChronicCond_Cancer                      0
# ChronicCond_ObstrPulmonary              0
# ChronicCond_Depression                  0
# ChronicCond_Diabetes                    0
# ChronicCond_IschemicHeart               0
# ChronicCond_Osteoporasis                0
# ChronicCond_rheumatoidarthritis         0
# ChronicCond_stroke                      0
# IPAnnualReimbursementAmt                0
# IPAnnualDeductibleAmt                   0
# OPAnnualReimbursementAmt                0
# OPAnnualDeductibleAmt                   0
# ClaimID                                 0
# ClaimStartDt                            0
# ClaimEndDt                              0
# Provider                                0
# InscClaimAmtReimbursed                  0
# AttendingPhysician                      0
# OperatingPhysician                 107856
# OtherPhysician                      86416
# AdmissionDt                        125525
# ClmAdmitDiagnosisCode                   0
# DeductibleAmtPaid                       0
# DischargeDt                        125525
# DiagnosisGroupCode                      0
# ClmDiagnosisCode_1                   2570
# ClmDiagnosisCode_2                  47646
# ClmDiagnosisCode_3                  76527
# ClmDiagnosisCode_4                  95519
# ClmDiagnosisCode_5                 108306
# ClmDiagnosisCode_6                 114932
# ClmDiagnosisCode_7                 119301
# ClmDiagnosisCode_8                 122359
# ClmDiagnosisCode_9                 125195
# ClmDiagnosisCode_10                133895
# ClmProcedureCode_1                 129596
# ClmProcedureCode_2                 133787
# ClmProcedureCode_3                 134820
# ClmProcedureCode_4                 135016
# ClmProcedureCode_5                 135043
# ClmProcedureCode_6                 135045
# ChronicCondScore                        0
# dtype: int64

# %%
#Training data
def check_numeric(value):
    try:
        pd.to_numeric(value)
        return 'Numeric'
    except ValueError:
        return 'String'

diagnosis_group_types = final_train['DiagnosisGroupCode'].apply(check_numeric)
diagnosis_code_numeric_mask = (diagnosis_group_types == 'Numeric')

print(diagnosis_group_types.value_counts())
final_train = final_train[diagnosis_code_numeric_mask]
# Out:
# DiagnosisGroupCode
# Numeric    556590
# String        113
# Name: count, dtype: int64

# %%
#Training data
def check_numeric(value):
    try:
        pd.to_numeric(value)
        return 'Numeric'
    except ValueError:
        return 'String'

claim_admit_diagnosis_types = final_train['ClmAdmitDiagnosisCode'].apply(check_numeric)
claim_admit_diagnosis_numeric_mask = (claim_admit_diagnosis_types == 'Numeric')

print(claim_admit_diagnosis_types.value_counts())
final_train = final_train[claim_admit_diagnosis_numeric_mask]
# Out:
# ClmAdmitDiagnosisCode
# Numeric    536728
# String      19862
# Name: count, dtype: int64

# %%
final_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 536728 entries, 0 to 558210
# Data columns (total 51 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           536728 non-null  object
#  1   Gender                           536728 non-null  int64
#  2   Race                             536728 non-null  int64
#  3   RenalDiseaseIndicator            536728 non-null  int64
#  4   State                            536728 non-null  int64
#  5   County                           536728 non-null  int64
#  6   ChronicCond_Alzheimer            536728 non-null  int64
#  7   ChronicCond_Heartfailure         536728 non-null  int64
#  8   ChronicCond_KidneyDisease        536728 non-null  int64
#  9   ChronicCond_Cancer               536728 non-null  int64
#  10  ChronicCond_ObstrPulmonary       536728 non-null  int64
#  11  ChronicCond_Depression           536728 non-null  int64
#  12  ChronicCond_Diabetes             536728 non-null  int64
#  13  ChronicCond_IschemicHeart        536728 non-null  int64
#  14  ChronicCond_Osteoporasis         536728 non-null  int64
#  15  ChronicCond_rheumatoidarthritis  536728 non-null  int64
#  16  ChronicCond_stroke               536728 non-null  int64
#  17  IPAnnualReimbursementAmt         536728 non-null  int64
#  18  IPAnnualDeductibleAmt            536728 non-null  int64
#  19  OPAnnualReimbursementAmt         536728 non-null  int64
#  20  OPAnnualDeductibleAmt            536728 non-null  int64
#  21  ClaimID                          536728 non-null  object
#  22  ClaimStartDt                     536728 non-null  object
#  23  ClaimEndDt                       536728 non-null  object
#  24  Provider                         536728 non-null  object
#  25  InscClaimAmtReimbursed           536728 non-null  int64
#  26  AttendingPhysician               536728 non-null  object
#  27  OperatingPhysician               111133 non-null  object
#  28  OtherPhysician                   197469 non-null  object
#  29  AdmissionDt                      39055 non-null   object
#  30  ClmAdmitDiagnosisCode            536728 non-null  object
#  31  DeductibleAmtPaid                536728 non-null  float64
#  32  DischargeDt                      39055 non-null   object
#  33  DiagnosisGroupCode               536728 non-null  object
#  34  ClmDiagnosisCode_1               526938 non-null  object
#  35  ClmDiagnosisCode_2               349495 non-null  object
#  36  ClmDiagnosisCode_3               235235 non-null  object
#  37  ClmDiagnosisCode_4               159618 non-null  object
#  38  ClmDiagnosisCode_5               108389 non-null  object
#  39  ClmDiagnosisCode_6               81655 non-null   object
#  40  ClmDiagnosisCode_7               63956 non-null   object
#  41  ClmDiagnosisCode_8               51630 non-null   object
#  42  ClmDiagnosisCode_9               40381 non-null   object
#  43  ClmDiagnosisCode_10              4921 non-null    object
#  44  ClmProcedureCode_1               22732 non-null   float64
#  45  ClmProcedureCode_2               5423 non-null    float64
#  46  ClmProcedureCode_3               963 non-null     float64
#  47  ClmProcedureCode_4               117 non-null     float64
#  48  ClmProcedureCode_5               9 non-null       float64
#  49  ClmProcedureCode_6               0 non-null       float64
#  50  ChronicCondScore                 536728 non-null  int64
# dtypes: float64(7), int64(22), object(22)
# memory usage: 212.9+ MB

# %%
final_train['ClmAdmitDiagnosisCode'] = final_train['ClmAdmitDiagnosisCode'].astype('int64')
final_train['DiagnosisGroupCode'] = final_train['DiagnosisGroupCode'].astype('int64')

# %%
final_train.shape
# Out:
# (536728, 51)

# %%
#Testing data
def check_numeric(value):
    try:
        pd.to_numeric(value)
        return 'Numeric'
    except ValueError:
        return 'String'

diagnosis_group_types = final_test['DiagnosisGroupCode'].apply(check_numeric)
diagnosis_code_numeric_mask = (diagnosis_group_types == 'Numeric')

print(diagnosis_group_types.value_counts())
final_test = final_test[diagnosis_code_numeric_mask]
# Out:
# DiagnosisGroupCode
# Numeric    135016
# String         29
# Name: count, dtype: int64

# %%
#Testing data
def check_numeric(value):
    try:
        pd.to_numeric(value)
        return 'Numeric'
    except ValueError:
        return 'String'

claim_admit_diagnosis_types = final_test['ClmAdmitDiagnosisCode'].apply(check_numeric)
claim_admit_diagnosis_numeric_mask = (claim_admit_diagnosis_types == 'Numeric')

print(claim_admit_diagnosis_types.value_counts())
final_test = final_test[claim_admit_diagnosis_numeric_mask]
# Out:
# ClmAdmitDiagnosisCode
# Numeric    130193
# String       4823
# Name: count, dtype: int64

# %%
final_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 130193 entries, 0 to 135391
# Data columns (total 51 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           130193 non-null  object
#  1   Gender                           130193 non-null  int64
#  2   Race                             130193 non-null  int64
#  3   RenalDiseaseIndicator            130193 non-null  int64
#  4   State                            130193 non-null  int64
#  5   County                           130193 non-null  int64
#  6   ChronicCond_Alzheimer            130193 non-null  int64
#  7   ChronicCond_Heartfailure         130193 non-null  int64
#  8   ChronicCond_KidneyDisease        130193 non-null  int64
#  9   ChronicCond_Cancer               130193 non-null  int64
#  10  ChronicCond_ObstrPulmonary       130193 non-null  int64
#  11  ChronicCond_Depression           130193 non-null  int64
#  12  ChronicCond_Diabetes             130193 non-null  int64
#  13  ChronicCond_IschemicHeart        130193 non-null  int64
#  14  ChronicCond_Osteoporasis         130193 non-null  int64
#  15  ChronicCond_rheumatoidarthritis  130193 non-null  int64
#  16  ChronicCond_stroke               130193 non-null  int64
#  17  IPAnnualReimbursementAmt         130193 non-null  int64
#  18  IPAnnualDeductibleAmt            130193 non-null  int64
#  19  OPAnnualReimbursementAmt         130193 non-null  int64
#  20  OPAnnualDeductibleAmt            130193 non-null  int64
#  21  ClaimID                          130193 non-null  object
#  22  ClaimStartDt                     130193 non-null  object
#  23  ClaimEndDt                       130193 non-null  object
#  24  Provider                         130193 non-null  object
#  25  InscClaimAmtReimbursed           130193 non-null  int64
#  26  AttendingPhysician               130193 non-null  object
#  27  OperatingPhysician               26450 non-null   object
#  28  OtherPhysician                   48125 non-null   object
#  29  AdmissionDt                      9184 non-null    object
#  30  ClmAdmitDiagnosisCode            130193 non-null  object
#  31  DeductibleAmtPaid                130193 non-null  float64
#  32  DischargeDt                      9184 non-null    object
#  33  DiagnosisGroupCode               130193 non-null  object
#  34  ClmDiagnosisCode_1               127779 non-null  object
#  35  ClmDiagnosisCode_2               84422 non-null   object
#  36  ClmDiagnosisCode_3               56732 non-null   object
#  37  ClmDiagnosisCode_4               38384 non-null   object
#  38  ClmDiagnosisCode_5               25916 non-null   object
#  39  ClmDiagnosisCode_6               19463 non-null   object
#  40  ClmDiagnosisCode_7               15221 non-null   object
#  41  ClmDiagnosisCode_8               12245 non-null   object
#  42  ClmDiagnosisCode_9               9496 non-null    object
#  43  ClmDiagnosisCode_10              1129 non-null    object
#  44  ClmProcedureCode_1               5309 non-null    float64
#  45  ClmProcedureCode_2               1235 non-null    float64
#  46  ClmProcedureCode_3               223 non-null     float64
#  47  ClmProcedureCode_4               29 non-null      float64
#  48  ClmProcedureCode_5               2 non-null       float64
#  49  ClmProcedureCode_6               0 non-null       float64
#  50  ChronicCondScore                 130193 non-null  int64
# dtypes: float64(7), int64(22), object(22)
# memory usage: 51.7+ MB

# %%
final_test['ClmAdmitDiagnosisCode'] = final_test['ClmAdmitDiagnosisCode'].astype('int64')
final_test['DiagnosisGroupCode'] = final_test['DiagnosisGroupCode'].astype('int64')

# %%
final_test.shape
# Out:
# (130193, 51)

# %%
final_train
# Out:
#             BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0        BENE11001       1     1                      0     39     230
# 1        BENE11001       1     1                      0     39     230
# 2        BENE11001       1     1                      0     39     230
# 3        BENE11002       2     1                      0     39     280
# 4        BENE11003       1     1                      0     52     590
# ...            ...     ...   ...                    ...    ...     ...
# 558206  BENE159198       2     1                      0     21      20
# 558207  BENE159198       2     1                      0     21      20
# 558208  BENE159198       2     1                      0     21      20
# 558209  BENE159198       2     1                      0     21      20
# 558210  BENE159198       2     1                      0     21      20
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         2
# 2                           1                         2
# 3                           2                         2
# 4                           1                         2
# ...                       ...                       ...
# 558206                      1                         1
# 558207                      1                         1
# 558208                      1                         1
# 558209                      1                         1
# 558210                      1                         1
#
#         ChronicCond_KidneyDisease  ChronicCond_Cancer  ...  \
# 0                               1                   2  ...
# 1                               1                   2  ...
# 2                               1                   2  ...
# 3                               2                   2  ...
# 4                               2                   2  ...
# ...                           ...                 ...  ...
# 558206                          2                   2  ...
# 558207                          2                   2  ...
# 558208                          2                   2  ...
# 558209                          2                   2  ...
# 558210                          2                   2  ...
#
#         ClmDiagnosisCode_8  ClmDiagnosisCode_9  ClmDiagnosisCode_10  \
# 0                    19889                5849                  NaN
# 1                      NaN                 NaN                  NaN
# 2                      NaN                 NaN                  NaN
# 3                      NaN                 NaN                  NaN
# 4                      NaN                 NaN                  NaN
# ...                    ...                 ...                  ...
# 558206                 NaN                 NaN                  NaN
# 558207                 NaN                 NaN                  NaN
# 558208                 NaN                 NaN                  NaN
# 558209                 NaN                 NaN                  NaN
# 558210                V103                 NaN                  NaN
#
#         ClmProcedureCode_1  ClmProcedureCode_2  ClmProcedureCode_3  \
# 0                      NaN                 NaN                 NaN
# 1                   7092.0                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_4  ClmProcedureCode_5  ClmProcedureCode_6  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ChronicCondScore
# 0                     15
# 1                     15
# 2                     15
# 3                     22
# 4                     20
# ...                  ...
# 558206                17
# 558207                17
# 558208                17
# 558209                17
# 558210                17
#
# [536728 rows x 51 columns]

# %%
final_test
# Out:
#             BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0        BENE11001       1     1                      0     39     230
# 1        BENE11001       1     1                      0     39     230
# 2        BENE11007       1     2                      0     45     610
# 3        BENE11007       1     2                      0     45     610
# 4        BENE11007       1     2                      0     45     610
# ...            ...     ...   ...                    ...    ...     ...
# 135387  BENE159193       2     1                      0     36     170
# 135388  BENE159193       2     1                      0     36     170
# 135389  BENE159194       1     1                      0     39     140
# 135390  BENE159196       2     1                      0      6     150
# 135391  BENE159197       1     1                      0     16     560
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         2
# 2                           1                         1
# 3                           1                         1
# 4                           1                         1
# ...                       ...                       ...
# 135387                      2                         2
# 135388                      2                         2
# 135389                      1                         2
# 135390                      2                         1
# 135391                      1                         1
#
#         ChronicCond_KidneyDisease  ChronicCond_Cancer  ...  \
# 0                               1                   2  ...
# 1                               1                   2  ...
# 2                               2                   2  ...
# 3                               2                   2  ...
# 4                               2                   2  ...
# ...                           ...                 ...  ...
# 135387                          2                   2  ...
# 135388                          2                   2  ...
# 135389                          2                   2  ...
# 135390                          1                   1  ...
# 135391                          2                   2  ...
#
#         ClmDiagnosisCode_8  ClmDiagnosisCode_9  ClmDiagnosisCode_10  \
# 0                      NaN                 NaN                  NaN
# 1                      NaN                 NaN                  NaN
# 2                      NaN                 NaN                  NaN
# 3                      NaN                 NaN                  NaN
# 4                      NaN                 NaN                  NaN
# ...                    ...                 ...                  ...
# 135387                 NaN                 NaN                  NaN
# 135388                 NaN                 NaN                  NaN
# 135389                 NaN                 NaN                  NaN
# 135390               V1251                2720                  NaN
# 135391                 NaN                 NaN                  NaN
#
#         ClmProcedureCode_1  ClmProcedureCode_2  ClmProcedureCode_3  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 135387                 NaN                 NaN                 NaN
# 135388                 NaN                 NaN                 NaN
# 135389                 NaN                 NaN                 NaN
# 135390                 NaN                 NaN                 NaN
# 135391                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_4  ClmProcedureCode_5  ClmProcedureCode_6  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 135387                 NaN                 NaN                 NaN
# 135388                 NaN                 NaN                 NaN
# 135389                 NaN                 NaN                 NaN
# 135390                 NaN                 NaN                 NaN
# 135391                 NaN                 NaN                 NaN
#
#         ChronicCondScore
# 0                     15
# 1                     15
# 2                     17
# 3                     17
# 4                     17
# ...                  ...
# 135387                22
# 135388                22
# 135389                21
# 135390                16
# 135391                19
#
# [130193 rows x 51 columns]

# %%
# extract numeric values from object tyoe values
final_train['BeneID_numeric'] = final_train['BeneID'].apply(lambda x: int(re.sub('[^0-9]', '', x)))
final_train['ClaimID_numeric'] = final_train['ClaimID'].apply(lambda x: int(re.sub('[^0-9]', '', x)))
final_train['Provider_numeric'] = final_train['Provider'].apply(lambda x: int(re.sub('[^0-9]', '', x)))
final_train['AttendingPhysician_numeric'] = final_train['AttendingPhysician'].apply(lambda x: int(re.sub('[^0-9]', '', x)))
final_train['OperatingPhysician_numeric'] = final_train['OperatingPhysician'].apply(lambda x: int(re.sub('[^0-9]', '', str(x))) if pd.notnull(x) and x != '' else 0)
final_train['OtherPhysician_numeric'] = final_train['OtherPhysician'].apply(lambda x: int(re.sub('[^0-9]', '', str(x))) if pd.notnull(x) and x != '' else 0)

# %%
# extract numeric values from object tyoe values
final_test['BeneID_numeric'] = final_test['BeneID'].apply(lambda x: int(re.sub('[^0-9]', '', x)))
final_test['ClaimID_numeric'] = final_test['ClaimID'].apply(lambda x: int(re.sub('[^0-9]', '', x)))
final_test['Provider_numeric'] = final_test['Provider'].apply(lambda x: int(re.sub('[^0-9]', '', x)))
final_test['AttendingPhysician_numeric'] = final_test['AttendingPhysician'].apply(lambda x: int(re.sub('[^0-9]', '', x)))
final_test['OperatingPhysician_numeric'] = final_test['OperatingPhysician'].apply(lambda x: int(re.sub('[^0-9]', '', str(x))) if pd.notnull(x) and x != '' else 0)
final_test['OtherPhysician_numeric'] = final_test['OtherPhysician'].apply(lambda x: int(re.sub('[^0-9]', '', str(x))) if pd.notnull(x) and x != '' else 0)

# %%
final_train
# Out:
#             BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0        BENE11001       1     1                      0     39     230
# 1        BENE11001       1     1                      0     39     230
# 2        BENE11001       1     1                      0     39     230
# 3        BENE11002       2     1                      0     39     280
# 4        BENE11003       1     1                      0     52     590
# ...            ...     ...   ...                    ...    ...     ...
# 558206  BENE159198       2     1                      0     21      20
# 558207  BENE159198       2     1                      0     21      20
# 558208  BENE159198       2     1                      0     21      20
# 558209  BENE159198       2     1                      0     21      20
# 558210  BENE159198       2     1                      0     21      20
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         2
# 2                           1                         2
# 3                           2                         2
# 4                           1                         2
# ...                       ...                       ...
# 558206                      1                         1
# 558207                      1                         1
# 558208                      1                         1
# 558209                      1                         1
# 558210                      1                         1
#
#         ChronicCond_KidneyDisease  ChronicCond_Cancer  ...  \
# 0                               1                   2  ...
# 1                               1                   2  ...
# 2                               1                   2  ...
# 3                               2                   2  ...
# 4                               2                   2  ...
# ...                           ...                 ...  ...
# 558206                          2                   2  ...
# 558207                          2                   2  ...
# 558208                          2                   2  ...
# 558209                          2                   2  ...
# 558210                          2                   2  ...
#
#         ClmProcedureCode_4  ClmProcedureCode_5  ClmProcedureCode_6  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ChronicCondScore  BeneID_numeric  ClaimID_numeric  Provider_numeric  \
# 0                     15           11001            46614             55912
# 1                     15           11001            66048             55907
# 2                     15           11001            68358             56046
# 3                     22           11002           624349             56011
# 4                     20           11003           189947             57610
# ...                  ...             ...              ...               ...
# 558206                17          159198           510792             53699
# 558207                17          159198           551294             53702
# 558208                17          159198           596444             53676
# 558209                17          159198           636992             53689
# 558210                17          159198           686139             53689
#
#         AttendingPhysician_numeric  OperatingPhysician_numeric  \
# 0                           390922                           0
# 1                           318495                      318495
# 2                           372395                           0
# 3                           326117                           0
# 4                           362868                           0
# ...                            ...                         ...
# 558206                      364188                      364188
# 558207                      423019                      332284
# 558208                      361063                           0
# 558209                      403198                           0
# 558210                      419379                           0
#
#         OtherPhysician_numeric
# 0                            0
# 1                            0
# 2                       324689
# 3                            0
# 4                            0
# ...                        ...
# 558206                  385752
# 558207                       0
# 558208                       0
# 558209                  419379
# 558210                  419379
#
# [536728 rows x 57 columns]

# %%
final_test
# Out:
#             BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0        BENE11001       1     1                      0     39     230
# 1        BENE11001       1     1                      0     39     230
# 2        BENE11007       1     2                      0     45     610
# 3        BENE11007       1     2                      0     45     610
# 4        BENE11007       1     2                      0     45     610
# ...            ...     ...   ...                    ...    ...     ...
# 135387  BENE159193       2     1                      0     36     170
# 135388  BENE159193       2     1                      0     36     170
# 135389  BENE159194       1     1                      0     39     140
# 135390  BENE159196       2     1                      0      6     150
# 135391  BENE159197       1     1                      0     16     560
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         2
# 2                           1                         1
# 3                           1                         1
# 4                           1                         1
# ...                       ...                       ...
# 135387                      2                         2
# 135388                      2                         2
# 135389                      1                         2
# 135390                      2                         1
# 135391                      1                         1
#
#         ChronicCond_KidneyDisease  ChronicCond_Cancer  ...  \
# 0                               1                   2  ...
# 1                               1                   2  ...
# 2                               2                   2  ...
# 3                               2                   2  ...
# 4                               2                   2  ...
# ...                           ...                 ...  ...
# 135387                          2                   2  ...
# 135388                          2                   2  ...
# 135389                          2                   2  ...
# 135390                          1                   1  ...
# 135391                          2                   2  ...
#
#         ClmProcedureCode_4  ClmProcedureCode_5  ClmProcedureCode_6  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 135387                 NaN                 NaN                 NaN
# 135388                 NaN                 NaN                 NaN
# 135389                 NaN                 NaN                 NaN
# 135390                 NaN                 NaN                 NaN
# 135391                 NaN                 NaN                 NaN
#
#         ChronicCondScore  BeneID_numeric  ClaimID_numeric  Provider_numeric  \
# 0                     15           11001           392397             55962
# 1                     15           11001           430760             56112
# 2                     17           11007           233081             56979
# 3                     17           11007           496381             56573
# 4                     17           11007           521391             56573
# ...                  ...             ...              ...               ...
# 135387                22          159193           483842             55485
# 135388                22          159193           554925             55485
# 135389                21          159194           347777             55889
# 135390                16          159196            47313             51854
# 135391                19          159197           357675             52983
#
#         AttendingPhysician_numeric  OperatingPhysician_numeric  \
# 0                           347633                           0
# 1                           381777                           0
# 2                           425311                           0
# 3                           393253                      347995
# 4                           417685                           0
# ...                            ...                         ...
# 135387                      369098                           0
# 135388                      431298                           0
# 135389                      406767                           0
# 135390                      377087                           0
# 135391                      354437                           0
#
#         OtherPhysician_numeric
# 0                       347633
# 1                       381777
# 2                       425311
# 3                            0
# 4                       382041
# ...                        ...
# 135387                       0
# 135388                       0
# 135389                  406767
# 135390                       0
# 135391                       0
#
# [130193 rows x 57 columns]

# %%
final_train.shape
# Out:
# (536728, 57)

# %%
final_test.shape
# Out:
# (130193, 57)

# %%
cols_to_drop = ['ClaimStartDt', 'ClaimEndDt', 'AdmissionDt', 'DischargeDt','BeneID','ClaimID','Provider','AttendingPhysician','OperatingPhysician','OtherPhysician']
final_train = final_train.drop(columns=cols_to_drop)
final_test = final_test.drop(columns=cols_to_drop)

# %%
final_train.shape
# Out:
# (536728, 47)

# %%
final_test.shape
# Out:
# (130193, 47)

# %%
final_train
# Out:
#         Gender  Race  RenalDiseaseIndicator  State  County  \
# 0            1     1                      0     39     230
# 1            1     1                      0     39     230
# 2            1     1                      0     39     230
# 3            2     1                      0     39     280
# 4            1     1                      0     52     590
# ...        ...   ...                    ...    ...     ...
# 558206       2     1                      0     21      20
# 558207       2     1                      0     21      20
# 558208       2     1                      0     21      20
# 558209       2     1                      0     21      20
# 558210       2     1                      0     21      20
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         2
# 2                           1                         2
# 3                           2                         2
# 4                           1                         2
# ...                       ...                       ...
# 558206                      1                         1
# 558207                      1                         1
# 558208                      1                         1
# 558209                      1                         1
# 558210                      1                         1
#
#         ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                               1                   2
# 1                               1                   2
# 2                               1                   2
# 3                               2                   2
# 4                               2                   2
# ...                           ...                 ...
# 558206                          2                   2
# 558207                          2                   2
# 558208                          2                   2
# 558209                          2                   2
# 558210                          2                   2
#
#         ChronicCond_ObstrPulmonary  ...  ClmProcedureCode_4  \
# 0                                2  ...                 NaN
# 1                                2  ...                 NaN
# 2                                2  ...                 NaN
# 3                                2  ...                 NaN
# 4                                2  ...                 NaN
# ...                            ...  ...                 ...
# 558206                           2  ...                 NaN
# 558207                           2  ...                 NaN
# 558208                           2  ...                 NaN
# 558209                           2  ...                 NaN
# 558210                           2  ...                 NaN
#
#         ClmProcedureCode_5  ClmProcedureCode_6  ChronicCondScore  \
# 0                      NaN                 NaN                15
# 1                      NaN                 NaN                15
# 2                      NaN                 NaN                15
# 3                      NaN                 NaN                22
# 4                      NaN                 NaN                20
# ...                    ...                 ...               ...
# 558206                 NaN                 NaN                17
# 558207                 NaN                 NaN                17
# 558208                 NaN                 NaN                17
# 558209                 NaN                 NaN                17
# 558210                 NaN                 NaN                17
#
#         BeneID_numeric  ClaimID_numeric  Provider_numeric  \
# 0                11001            46614             55912
# 1                11001            66048             55907
# 2                11001            68358             56046
# 3                11002           624349             56011
# 4                11003           189947             57610
# ...                ...              ...               ...
# 558206          159198           510792             53699
# 558207          159198           551294             53702
# 558208          159198           596444             53676
# 558209          159198           636992             53689
# 558210          159198           686139             53689
#
#         AttendingPhysician_numeric  OperatingPhysician_numeric  \
# 0                           390922                           0
# 1                           318495                      318495
# 2                           372395                           0
# 3                           326117                           0
# 4                           362868                           0
# ...                            ...                         ...
# 558206                      364188                      364188
# 558207                      423019                      332284
# 558208                      361063                           0
# 558209                      403198                           0
# 558210                      419379                           0
#
#         OtherPhysician_numeric
# 0                            0
# 1                            0
# 2                       324689
# 3                            0
# 4                            0
# ...                        ...
# 558206                  385752
# 558207                       0
# 558208                       0
# 558209                  419379
# 558210                  419379
#
# [536728 rows x 47 columns]

# %%
final_test
# Out:
#         Gender  Race  RenalDiseaseIndicator  State  County  \
# 0            1     1                      0     39     230
# 1            1     1                      0     39     230
# 2            1     2                      0     45     610
# 3            1     2                      0     45     610
# 4            1     2                      0     45     610
# ...        ...   ...                    ...    ...     ...
# 135387       2     1                      0     36     170
# 135388       2     1                      0     36     170
# 135389       1     1                      0     39     140
# 135390       2     1                      0      6     150
# 135391       1     1                      0     16     560
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         2
# 2                           1                         1
# 3                           1                         1
# 4                           1                         1
# ...                       ...                       ...
# 135387                      2                         2
# 135388                      2                         2
# 135389                      1                         2
# 135390                      2                         1
# 135391                      1                         1
#
#         ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                               1                   2
# 1                               1                   2
# 2                               2                   2
# 3                               2                   2
# 4                               2                   2
# ...                           ...                 ...
# 135387                          2                   2
# 135388                          2                   2
# 135389                          2                   2
# 135390                          1                   1
# 135391                          2                   2
#
#         ChronicCond_ObstrPulmonary  ...  ClmProcedureCode_4  \
# 0                                2  ...                 NaN
# 1                                2  ...                 NaN
# 2                                2  ...                 NaN
# 3                                2  ...                 NaN
# 4                                2  ...                 NaN
# ...                            ...  ...                 ...
# 135387                           2  ...                 NaN
# 135388                           2  ...                 NaN
# 135389                           2  ...                 NaN
# 135390                           2  ...                 NaN
# 135391                           2  ...                 NaN
#
#         ClmProcedureCode_5  ClmProcedureCode_6  ChronicCondScore  \
# 0                      NaN                 NaN                15
# 1                      NaN                 NaN                15
# 2                      NaN                 NaN                17
# 3                      NaN                 NaN                17
# 4                      NaN                 NaN                17
# ...                    ...                 ...               ...
# 135387                 NaN                 NaN                22
# 135388                 NaN                 NaN                22
# 135389                 NaN                 NaN                21
# 135390                 NaN                 NaN                16
# 135391                 NaN                 NaN                19
#
#         BeneID_numeric  ClaimID_numeric  Provider_numeric  \
# 0                11001           392397             55962
# 1                11001           430760             56112
# 2                11007           233081             56979
# 3                11007           496381             56573
# 4                11007           521391             56573
# ...                ...              ...               ...
# 135387          159193           483842             55485
# 135388          159193           554925             55485
# 135389          159194           347777             55889
# 135390          159196            47313             51854
# 135391          159197           357675             52983
#
#         AttendingPhysician_numeric  OperatingPhysician_numeric  \
# 0                           347633                           0
# 1                           381777                           0
# 2                           425311                           0
# 3                           393253                      347995
# 4                           417685                           0
# ...                            ...                         ...
# 135387                      369098                           0
# 135388                      431298                           0
# 135389                      406767                           0
# 135390                      377087                           0
# 135391                      354437                           0
#
#         OtherPhysician_numeric
# 0                       347633
# 1                       381777
# 2                       425311
# 3                            0
# 4                       382041
# ...                        ...
# 135387                       0
# 135388                       0
# 135389                  406767
# 135390                       0
# 135391                       0
#
# [130193 rows x 47 columns]

# %%
cols_to_convert = ['ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5','ClmProcedureCode_6']

# %%
def enumerate_values(final_train, cols_to_convert):
    value_to_int = {}
    for col in cols_to_convert:
        unique_values = final_train[col].unique()
        for value in unique_values:
            if pd.notnull(value) and value not in value_to_int:
                value_to_int[value] = len(value_to_int) + 1
    value_to_int[np.nan] = 0  # Assigning 0 to NaN

    for col in cols_to_convert:
        final_train[col] = final_train[col].map(value_to_int)
 
    return final_train

final_train = enumerate_values(final_train, cols_to_convert)

# %%
def enumerate_values(final_test, cols_to_convert):
    value_to_int = {}
    for col in cols_to_convert:
        unique_values = final_test[col].unique()
        for value in unique_values:
            if pd.notnull(value) and value not in value_to_int:
                value_to_int[value] = len(value_to_int) + 1
    value_to_int[np.nan] = 0  # Assigning 0 to NaN

    for col in cols_to_convert:
        final_test[col] = final_test[col].map(value_to_int)
 
    return final_test

final_test = enumerate_values(final_test, cols_to_convert)

# %%
diagnosis_weights = {
    'ClmDiagnosisCode_1': 1,
    'ClmDiagnosisCode_2': 1,
    'ClmDiagnosisCode_3': 1,
    'ClmDiagnosisCode_4': 1,
    'ClmDiagnosisCode_5': 1,
    'ClmDiagnosisCode_6': 1,
    'ClmDiagnosisCode_7': 1,
    'ClmDiagnosisCode_8': 1,
    'ClmDiagnosisCode_9': 1,
    'ClmDiagnosisCode_10': 1
}

procedure_weights = {
    'ClmProcedureCode_1': 1,
    'ClmProcedureCode_2': 1,
    'ClmProcedureCode_3': 1,
    'ClmProcedureCode_4': 1,
    'ClmProcedureCode_5': 1,
    'ClmProcedureCode_6': 1
}

# Calculate score for each row
final_train['DiagnosisScore'] = (final_train.filter(regex='ClmDiagnosisCode_*')
                          .apply(lambda x: x * diagnosis_weights.get(x.name, 0))
                          .sum(axis=1, skipna=True))

final_train['ProcedureScore'] = (final_train.filter(regex='ClmProcedureCode_*')
                          .apply(lambda x: x * procedure_weights.get(x.name, 0))
                          .sum(axis=1, skipna=True))
final_test['DiagnosisScore'] = (final_test.filter(regex='ClmDiagnosisCode_*')
                          .apply(lambda x: x * diagnosis_weights.get(x.name, 0))
                          .sum(axis=1, skipna=True))

final_test['ProcedureScore'] = (final_test.filter(regex='ClmProcedureCode_*')
                          .apply(lambda x: x * procedure_weights.get(x.name, 0))
                          .sum(axis=1, skipna=True))

# %%
final_train
# Out:
#         Gender  Race  RenalDiseaseIndicator  State  County  \
# 0            1     1                      0     39     230
# 1            1     1                      0     39     230
# 2            1     1                      0     39     230
# 3            2     1                      0     39     280
# 4            1     1                      0     52     590
# ...        ...   ...                    ...    ...     ...
# 558206       2     1                      0     21      20
# 558207       2     1                      0     21      20
# 558208       2     1                      0     21      20
# 558209       2     1                      0     21      20
# 558210       2     1                      0     21      20
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         2
# 2                           1                         2
# 3                           2                         2
# 4                           1                         2
# ...                       ...                       ...
# 558206                      1                         1
# 558207                      1                         1
# 558208                      1                         1
# 558209                      1                         1
# 558210                      1                         1
#
#         ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                               1                   2
# 1                               1                   2
# 2                               1                   2
# 3                               2                   2
# 4                               2                   2
# ...                           ...                 ...
# 558206                          2                   2
# 558207                          2                   2
# 558208                          2                   2
# 558209                          2                   2
# 558210                          2                   2
#
#         ChronicCond_ObstrPulmonary  ...  ClmProcedureCode_6  ChronicCondScore  \
# 0                                2  ...                   0                15
# 1                                2  ...                   0                15
# 2                                2  ...                   0                15
# 3                                2  ...                   0                22
# 4                                2  ...                   0                20
# ...                            ...  ...                 ...               ...
# 558206                           2  ...                   0                17
# 558207                           2  ...                   0                17
# 558208                           2  ...                   0                17
# 558209                           2  ...                   0                17
# 558210                           2  ...                   0                17
#
#         BeneID_numeric  ClaimID_numeric  Provider_numeric  \
# 0                11001            46614             55912
# 1                11001            66048             55907
# 2                11001            68358             56046
# 3                11002           624349             56011
# 4                11003           189947             57610
# ...                ...              ...               ...
# 558206          159198           510792             53699
# 558207          159198           551294             53702
# 558208          159198           596444             53676
# 558209          159198           636992             53689
# 558210          159198           686139             53689
#
#         AttendingPhysician_numeric  OperatingPhysician_numeric  \
# 0                           390922                           0
# 1                           318495                      318495
# 2                           372395                           0
# 3                           326117                           0
# 4                           362868                           0
# ...                            ...                         ...
# 558206                      364188                      364188
# 558207                      423019                      332284
# 558208                      361063                           0
# 558209                      403198                           0
# 558210                      419379                           0
#
#         OtherPhysician_numeric  DiagnosisScore  ProcedureScore
# 0                            0           10772               0
# 1                            0            1219           10962
# 2                       324689            8865               0
# 3                            0            2169               0
# 4                            0               5               0
# ...                        ...             ...             ...
# 558206                  385752           12113               0
# 558207                       0           10438               0
# 558208                       0             630               0
# 558209                  419379               0               0
# 558210                  419379           13375               0
#
# [536728 rows x 49 columns]

# %%
final_test
# Out:
#         Gender  Race  RenalDiseaseIndicator  State  County  \
# 0            1     1                      0     39     230
# 1            1     1                      0     39     230
# 2            1     2                      0     45     610
# 3            1     2                      0     45     610
# 4            1     2                      0     45     610
# ...        ...   ...                    ...    ...     ...
# 135387       2     1                      0     36     170
# 135388       2     1                      0     36     170
# 135389       1     1                      0     39     140
# 135390       2     1                      0      6     150
# 135391       1     1                      0     16     560
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         2
# 2                           1                         1
# 3                           1                         1
# 4                           1                         1
# ...                       ...                       ...
# 135387                      2                         2
# 135388                      2                         2
# 135389                      1                         2
# 135390                      2                         1
# 135391                      1                         1
#
#         ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                               1                   2
# 1                               1                   2
# 2                               2                   2
# 3                               2                   2
# 4                               2                   2
# ...                           ...                 ...
# 135387                          2                   2
# 135388                          2                   2
# 135389                          2                   2
# 135390                          1                   1
# 135391                          2                   2
#
#         ChronicCond_ObstrPulmonary  ...  ClmProcedureCode_6  ChronicCondScore  \
# 0                                2  ...                   0                15
# 1                                2  ...                   0                15
# 2                                2  ...                   0                17
# 3                                2  ...                   0                17
# 4                                2  ...                   0                17
# ...                            ...  ...                 ...               ...
# 135387                           2  ...                   0                22
# 135388                           2  ...                   0                22
# 135389                           2  ...                   0                21
# 135390                           2  ...                   0                16
# 135391                           2  ...                   0                19
#
#         BeneID_numeric  ClaimID_numeric  Provider_numeric  \
# 0                11001           392397             55962
# 1                11001           430760             56112
# 2                11007           233081             56979
# 3                11007           496381             56573
# 4                11007           521391             56573
# ...                ...              ...               ...
# 135387          159193           483842             55485
# 135388          159193           554925             55485
# 135389          159194           347777             55889
# 135390          159196            47313             51854
# 135391          159197           357675             52983
#
#         AttendingPhysician_numeric  OperatingPhysician_numeric  \
# 0                           347633                           0
# 1                           381777                           0
# 2                           425311                           0
# 3                           393253                      347995
# 4                           417685                           0
# ...                            ...                         ...
# 135387                      369098                           0
# 135388                      431298                           0
# 135389                      406767                           0
# 135390                      377087                           0
# 135391                      354437                           0
#
#         OtherPhysician_numeric  DiagnosisScore  ProcedureScore
# 0                       347633            2470               0
# 1                       381777            8334               0
# 2                       425311               3               0
# 3                            0             293               0
# 4                       382041               5               0
# ...                        ...             ...             ...
# 135387                       0           13819               0
# 135388                       0            3429               0
# 135389                  406767            4009               0
# 135390                       0           10710               0
# 135391                       0               0               0
#
# [130193 rows x 49 columns]

# %%
# correlation_matrix = final_train.corr()  
# correlation_matrix

# Move 'InscClaimAmtReimbursed' column to the first position
cols = list(final_train.columns)
cols.remove('InscClaimAmtReimbursed')
cols.insert(0, 'InscClaimAmtReimbursed')

# Create a new DataFrame with columns rearranged
final_train_reordered = final_train[cols]

# Calculate correlation matrix
correlation_matrix = final_train_reordered.corr()

# Display correlation matrix
correlation_matrix
# Out:
#                                  InscClaimAmtReimbursed    Gender      Race  \
# InscClaimAmtReimbursed                         1.000000 -0.001899 -0.000560
# Gender                                        -0.001899  1.000000  0.002115
# Race                                          -0.000560  0.002115  1.000000
# RenalDiseaseIndicator                          0.060881  0.003338 -0.000352
# State                                         -0.000099  0.007816 -0.055540
# County                                        -0.002042  0.004311 -0.005961
# ChronicCond_Alzheimer                         -0.033804 -0.009959 -0.003823
# ChronicCond_Heartfailure                      -0.058994  0.000303  0.002380
# ChronicCond_KidneyDisease                     -0.098544  0.000654 -0.005330
# ChronicCond_Cancer                            -0.027204  0.015823  0.012917
# ChronicCond_ObstrPulmonary                    -0.068376 -0.005596 -0.000822
# ChronicCond_Depression                        -0.017959 -0.021930 -0.009313
# ChronicCond_Diabetes                          -0.044980 -0.013584 -0.004427
# ChronicCond_IschemicHeart                     -0.052610 -0.000943  0.007963
# ChronicCond_Osteoporasis                      -0.009973 -0.012945  0.002076
# ChronicCond_rheumatoidarthritis               -0.016836 -0.006609 -0.002124
# ChronicCond_stroke                            -0.047325  0.002439  0.002188
# IPAnnualReimbursementAmt                       0.383292  0.000103 -0.000724
# IPAnnualDeductibleAmt                          0.224201 -0.001780 -0.001995
# OPAnnualReimbursementAmt                       0.066697  0.008082  0.011917
# OPAnnualDeductibleAmt                          0.032241  0.005845  0.007563
# ClmAdmitDiagnosisCode                          0.279438 -0.000925 -0.001250
# DeductibleAmtPaid                              0.648785 -0.002281 -0.002301
# DiagnosisGroupCode                             0.558078 -0.000949 -0.002302
# ClmDiagnosisCode_1                            -0.018407  0.003215 -0.002885
# ClmDiagnosisCode_2                             0.079692  0.000358 -0.000627
# ClmDiagnosisCode_3                             0.127834  0.000683  0.001314
# ClmDiagnosisCode_4                             0.180150  0.001702  0.001370
# ClmDiagnosisCode_5                             0.221549  0.002232 -0.000628
# ClmDiagnosisCode_6                             0.249101 -0.001353  0.001032
# ClmDiagnosisCode_7                             0.273101 -0.002406  0.000395
# ClmDiagnosisCode_8                             0.284792 -0.000081  0.001568
# ClmDiagnosisCode_9                             0.301358 -0.002611 -0.000099
# ClmDiagnosisCode_10                            0.132683 -0.003815  0.002519
# ClmProcedureCode_1                             0.640670 -0.001388 -0.001810
# ClmProcedureCode_2                             0.406776 -0.000950 -0.001694
# ClmProcedureCode_3                             0.204818 -0.001777 -0.000986
# ClmProcedureCode_4                             0.081056  0.000582 -0.000293
# ClmProcedureCode_5                             0.025740  0.002631 -0.000839
# ClmProcedureCode_6                                  NaN       NaN       NaN
# ChronicCondScore                              -0.091846 -0.011652 -0.000719
# BeneID_numeric                                -0.000552  0.001444  0.003942
# ClaimID_numeric                               -0.319491  0.001018  0.001603
# Provider_numeric                              -0.011600  0.006139 -0.053626
# AttendingPhysician_numeric                     0.011736 -0.000560  0.003283
# OperatingPhysician_numeric                     0.263042 -0.003421  0.000468
# OtherPhysician_numeric                        -0.086468 -0.003557  0.001019
# DiagnosisScore                                 0.312982  0.001080 -0.000066
# ProcedureScore                                 0.631297 -0.001518 -0.002061
#
#                                  RenalDiseaseIndicator     State    County  \
# InscClaimAmtReimbursed                        0.060881 -0.000099 -0.002042
# Gender                                        0.003338  0.007816  0.004311
# Race                                         -0.000352 -0.055540 -0.005961
# RenalDiseaseIndicator                         1.000000  0.000712  0.010106
# State                                         0.000712  1.000000  0.119705
# County                                        0.010106  0.119705  1.000000
# ChronicCond_Alzheimer                        -0.109551  0.003232 -0.006871
# ChronicCond_Heartfailure                     -0.191431  0.001693 -0.009317
# ChronicCond_KidneyDisease                    -0.442775  0.002073 -0.015349
# ChronicCond_Cancer                           -0.039822  0.002072 -0.004876
# ChronicCond_ObstrPulmonary                   -0.147704  0.000177 -0.010403
# ChronicCond_Depression                       -0.093816  0.001855 -0.010703
# ChronicCond_Diabetes                         -0.186288  0.002434 -0.004379
# ChronicCond_IschemicHeart                    -0.144331  0.002568 -0.007360
# ChronicCond_Osteoporasis                     -0.041890 -0.000781 -0.009511
# ChronicCond_rheumatoidarthritis              -0.059358  0.000977 -0.001779
# ChronicCond_stroke                           -0.105333  0.002250 -0.003650
# IPAnnualReimbursementAmt                      0.191448 -0.005777  0.001340
# IPAnnualDeductibleAmt                         0.174073 -0.009271  0.002522
# OPAnnualReimbursementAmt                      0.342626 -0.008000  0.007164
# OPAnnualDeductibleAmt                         0.344546 -0.009549  0.006851
# ClmAdmitDiagnosisCode                         0.028416 -0.000108  0.000969
# DeductibleAmtPaid                             0.041572 -0.000897 -0.001851
# DiagnosisGroupCode                            0.039209 -0.001705 -0.002057
# ClmDiagnosisCode_1                           -0.028303  0.000986  0.000303
# ClmDiagnosisCode_2                            0.001727 -0.001603 -0.001355
# ClmDiagnosisCode_3                            0.018665  0.001785 -0.000314
# ClmDiagnosisCode_4                            0.027239  0.000360 -0.002169
# ClmDiagnosisCode_5                            0.031478  0.000841  0.000756
# ClmDiagnosisCode_6                            0.032626 -0.000217 -0.001260
# ClmDiagnosisCode_7                            0.033468 -0.000793  0.000518
# ClmDiagnosisCode_8                            0.036529  0.001315  0.000797
# ClmDiagnosisCode_9                            0.033967 -0.001475 -0.002385
# ClmDiagnosisCode_10                           0.008998 -0.000184 -0.000615
# ClmProcedureCode_1                            0.041032  0.000128 -0.001190
# ClmProcedureCode_2                            0.017865 -0.002954 -0.001112
# ClmProcedureCode_3                            0.008648 -0.002079 -0.001089
# ClmProcedureCode_4                            0.004580 -0.000412  0.001482
# ClmProcedureCode_5                            0.001368 -0.001354 -0.000866
# ClmProcedureCode_6                                 NaN       NaN       NaN
# ChronicCondScore                             -0.308998  0.003498 -0.016672
# BeneID_numeric                                0.004962 -0.001161 -0.004629
# ClaimID_numeric                              -0.029958  0.001164  0.003555
# Provider_numeric                              0.001927  0.797883  0.082726
# AttendingPhysician_numeric                    0.001799  0.007712  0.007215
# OperatingPhysician_numeric                    0.039453  0.001090  0.001243
# OtherPhysician_numeric                       -0.032438 -0.000706  0.002947
# DiagnosisScore                                0.029518  0.000409 -0.001105
# ProcedureScore                                0.036706 -0.001357 -0.001337
#
#                                  ChronicCond_Alzheimer  \
# InscClaimAmtReimbursed                       -0.033804
# Gender                                       -0.009959
# Race                                         -0.003823
# RenalDiseaseIndicator                        -0.109551
# State                                         0.003232
# County                                       -0.006871
# ChronicCond_Alzheimer                         1.000000
# ChronicCond_Heartfailure                      0.188842
# ChronicCond_KidneyDisease                     0.184552
# ChronicCond_Cancer                            0.048997
# ChronicCond_ObstrPulmonary                    0.172118
# ChronicCond_Depression                        0.172185
# ChronicCond_Diabetes                          0.185507
# ChronicCond_IschemicHeart                     0.150439
# ChronicCond_Osteoporasis                      0.077876
# ChronicCond_rheumatoidarthritis               0.088760
# ChronicCond_stroke                            0.130457
# IPAnnualReimbursementAmt                     -0.131061
# IPAnnualDeductibleAmt                        -0.163024
# OPAnnualReimbursementAmt                     -0.084965
# OPAnnualDeductibleAmt                        -0.088668
# ClmAdmitDiagnosisCode                        -0.038463
# DeductibleAmtPaid                            -0.056272
# DiagnosisGroupCode                           -0.051585
# ClmDiagnosisCode_1                            0.000881
# ClmDiagnosisCode_2                           -0.008597
# ClmDiagnosisCode_3                           -0.021564
# ClmDiagnosisCode_4                           -0.031409
# ClmDiagnosisCode_5                           -0.037751
# ClmDiagnosisCode_6                           -0.039781
# ClmDiagnosisCode_7                           -0.042752
# ClmDiagnosisCode_8                           -0.042954
# ClmDiagnosisCode_9                           -0.040191
# ClmDiagnosisCode_10                          -0.011623
# ClmProcedureCode_1                           -0.033658
# ClmProcedureCode_2                           -0.010427
# ClmProcedureCode_3                           -0.003236
# ClmProcedureCode_4                           -0.001053
# ClmProcedureCode_5                            0.000646
# ClmProcedureCode_6                                 NaN
# ChronicCondScore                              0.481355
# BeneID_numeric                               -0.000920
# ClaimID_numeric                               0.037915
# Provider_numeric                              0.005510
# AttendingPhysician_numeric                   -0.002924
# OperatingPhysician_numeric                   -0.012326
# OtherPhysician_numeric                        0.047340
# DiagnosisScore                               -0.048813
# ProcedureScore                               -0.027790
#
#                                  ChronicCond_Heartfailure  \
# InscClaimAmtReimbursed                          -0.058994
# Gender                                           0.000303
# Race                                             0.002380
# RenalDiseaseIndicator                           -0.191431
# State                                            0.001693
# County                                          -0.009317
# ChronicCond_Alzheimer                            0.188842
# ChronicCond_Heartfailure                         1.000000
# ChronicCond_KidneyDisease                        0.307399
# ChronicCond_Cancer                               0.075856
# ChronicCond_ObstrPulmonary                       0.257470
# ChronicCond_Depression                           0.155955
# ChronicCond_Diabetes                             0.268511
# ChronicCond_IschemicHeart                        0.267761
# ChronicCond_Osteoporasis                         0.082658
# ChronicCond_rheumatoidarthritis                  0.119002
# ChronicCond_stroke                               0.137229
# IPAnnualReimbursementAmt                        -0.187341
# IPAnnualDeductibleAmt                           -0.200711
# OPAnnualReimbursementAmt                        -0.160602
# OPAnnualDeductibleAmt                           -0.161992
# ClmAdmitDiagnosisCode                           -0.051741
# DeductibleAmtPaid                               -0.072397
# DiagnosisGroupCode                              -0.057324
# ClmDiagnosisCode_1                               0.026943
# ClmDiagnosisCode_2                              -0.005966
# ClmDiagnosisCode_3                              -0.021555
# ClmDiagnosisCode_4                              -0.032759
# ClmDiagnosisCode_5                              -0.041339
# ClmDiagnosisCode_6                              -0.044175
# ClmDiagnosisCode_7                              -0.047842
# ClmDiagnosisCode_8                              -0.051304
# ClmDiagnosisCode_9                              -0.051395
# ClmDiagnosisCode_10                             -0.013755
# ClmProcedureCode_1                              -0.052407
# ClmProcedureCode_2                              -0.025588
# ClmProcedureCode_3                              -0.011372
# ClmProcedureCode_4                              -0.003593
# ClmProcedureCode_5                              -0.000640
# ClmProcedureCode_6                                    NaN
# ChronicCondScore                                 0.571065
# BeneID_numeric                                  -0.001366
# ClaimID_numeric                                  0.048102
# Provider_numeric                                -0.000087
# AttendingPhysician_numeric                      -0.001390
# OperatingPhysician_numeric                      -0.025003
# OtherPhysician_numeric                           0.056238
# DiagnosisScore                                  -0.044294
# ProcedureScore                                  -0.047807
#
#                                  ChronicCond_KidneyDisease  \
# InscClaimAmtReimbursed                           -0.098544
# Gender                                            0.000654
# Race                                             -0.005330
# RenalDiseaseIndicator                            -0.442775
# State                                             0.002073
# County                                           -0.015349
# ChronicCond_Alzheimer                             0.184552
# ChronicCond_Heartfailure                          0.307399
# ChronicCond_KidneyDisease                         1.000000
# ChronicCond_Cancer                                0.109096
# ChronicCond_ObstrPulmonary                        0.257195
# ChronicCond_Depression                            0.164129
# ChronicCond_Diabetes                              0.306412
# ChronicCond_IschemicHeart                         0.238090
# ChronicCond_Osteoporasis                          0.089664
# ChronicCond_rheumatoidarthritis                   0.137846
# ChronicCond_stroke                                0.146531
# IPAnnualReimbursementAmt                         -0.276767
# IPAnnualDeductibleAmt                            -0.275462
# OPAnnualReimbursementAmt                         -0.248278
# OPAnnualDeductibleAmt                            -0.252750
# ClmAdmitDiagnosisCode                            -0.066480
# DeductibleAmtPaid                                -0.104621
# DiagnosisGroupCode                               -0.095385
# ClmDiagnosisCode_1                                0.024910
# ClmDiagnosisCode_2                               -0.009570
# ClmDiagnosisCode_3                               -0.030371
# ClmDiagnosisCode_4                               -0.045156
# ClmDiagnosisCode_5                               -0.056501
# ClmDiagnosisCode_6                               -0.061560
# ClmDiagnosisCode_7                               -0.064684
# ClmDiagnosisCode_8                               -0.069916
# ClmDiagnosisCode_9                               -0.069818
# ClmDiagnosisCode_10                              -0.023603
# ClmProcedureCode_1                               -0.082213
# ClmProcedureCode_2                               -0.038633
# ClmProcedureCode_3                               -0.016623
# ClmProcedureCode_4                               -0.004924
# ClmProcedureCode_5                               -0.002108
# ClmProcedureCode_6                                     NaN
# ChronicCondScore                                  0.585332
# BeneID_numeric                                   -0.000153
# ClaimID_numeric                                   0.064287
# Provider_numeric                                  0.001793
# AttendingPhysician_numeric                       -0.001863
# OperatingPhysician_numeric                       -0.049733
# OtherPhysician_numeric                            0.059475
# DiagnosisScore                                   -0.065731
# ProcedureScore                                   -0.074233
#
#                                  ChronicCond_Cancer  ...  ClmProcedureCode_6  \
# InscClaimAmtReimbursed                    -0.027204  ...                 NaN
# Gender                                     0.015823  ...                 NaN
# Race                                       0.012917  ...                 NaN
# RenalDiseaseIndicator                     -0.039822  ...                 NaN
# State                                      0.002072  ...                 NaN
# County                                    -0.004876  ...                 NaN
# ChronicCond_Alzheimer                      0.048997  ...                 NaN
# ChronicCond_Heartfailure                   0.075856  ...                 NaN
# ChronicCond_KidneyDisease                  0.109096  ...                 NaN
# ChronicCond_Cancer                         1.000000  ...                 NaN
# ChronicCond_ObstrPulmonary                 0.110358  ...                 NaN
# ChronicCond_Depression                     0.034698  ...                 NaN
# ChronicCond_Diabetes                       0.081267  ...                 NaN
# ChronicCond_IschemicHeart                  0.083053  ...                 NaN
# ChronicCond_Osteoporasis                   0.046164  ...                 NaN
# ChronicCond_rheumatoidarthritis            0.056171  ...                 NaN
# ChronicCond_stroke                         0.039901  ...                 NaN
# IPAnnualReimbursementAmt                  -0.089433  ...                 NaN
# IPAnnualDeductibleAmt                     -0.087826  ...                 NaN
# OPAnnualReimbursementAmt                  -0.040177  ...                 NaN
# OPAnnualDeductibleAmt                     -0.049079  ...                 NaN
# ClmAdmitDiagnosisCode                     -0.014917  ...                 NaN
# DeductibleAmtPaid                         -0.030822  ...                 NaN
# DiagnosisGroupCode                        -0.025934  ...                 NaN
# ClmDiagnosisCode_1                         0.007442  ...                 NaN
# ClmDiagnosisCode_2                        -0.007526  ...                 NaN
# ClmDiagnosisCode_3                        -0.008843  ...                 NaN
# ClmDiagnosisCode_4                        -0.013636  ...                 NaN
# ClmDiagnosisCode_5                        -0.019785  ...                 NaN
# ClmDiagnosisCode_6                        -0.022167  ...                 NaN
# ClmDiagnosisCode_7                        -0.020335  ...                 NaN
# ClmDiagnosisCode_8                        -0.022258  ...                 NaN
# ClmDiagnosisCode_9                        -0.021642  ...                 NaN
# ClmDiagnosisCode_10                       -0.008100  ...                 NaN
# ClmProcedureCode_1                        -0.030427  ...                 NaN
# ClmProcedureCode_2                        -0.014770  ...                 NaN
# ClmProcedureCode_3                        -0.006888  ...                 NaN
# ClmProcedureCode_4                        -0.004168  ...                 NaN
# ClmProcedureCode_5                        -0.000814  ...                 NaN
# ClmProcedureCode_6                              NaN  ...                 NaN
# ChronicCondScore                           0.288605  ...                 NaN
# BeneID_numeric                            -0.003155  ...                 NaN
# ClaimID_numeric                            0.020382  ...                 NaN
# Provider_numeric                           0.000562  ...                 NaN
# AttendingPhysician_numeric                -0.000571  ...                 NaN
# OperatingPhysician_numeric                -0.025524  ...                 NaN
# OtherPhysician_numeric                     0.026620  ...                 NaN
# DiagnosisScore                            -0.022798  ...                 NaN
# ProcedureScore                            -0.027888  ...                 NaN
#
#                                  ChronicCondScore  BeneID_numeric  \
# InscClaimAmtReimbursed                  -0.091846       -0.000552
# Gender                                  -0.011652        0.001444
# Race                                    -0.000719        0.003942
# RenalDiseaseIndicator                   -0.308998        0.004962
# State                                    0.003498       -0.001161
# County                                  -0.016672       -0.004629
# ChronicCond_Alzheimer                    0.481355       -0.000920
# ChronicCond_Heartfailure                 0.571065       -0.001366
# ChronicCond_KidneyDisease                0.585332       -0.000153
# ChronicCond_Cancer                       0.288605       -0.003155
# ChronicCond_ObstrPulmonary               0.533215        0.002264
# ChronicCond_Depression                   0.463475       -0.006615
# ChronicCond_Diabetes                     0.572845       -0.003317
# ChronicCond_IschemicHeart                0.515661        0.002491
# ChronicCond_Osteoporasis                 0.362447        0.000696
# ChronicCond_rheumatoidarthritis          0.425023       -0.001486
# ChronicCond_stroke                       0.329205        0.001630
# IPAnnualReimbursementAmt                -0.311607       -0.001007
# IPAnnualDeductibleAmt                   -0.339227       -0.000281
# OPAnnualReimbursementAmt                -0.219460        0.010636
# OPAnnualDeductibleAmt                   -0.230009        0.008093
# ClmAdmitDiagnosisCode                   -0.092628        0.001203
# DeductibleAmtPaid                       -0.121020       -0.000288
# DiagnosisGroupCode                      -0.102077        0.000238
# ClmDiagnosisCode_1                       0.020728        0.022130
# ClmDiagnosisCode_2                      -0.017113        0.000980
# ClmDiagnosisCode_3                      -0.043521        0.000026
# ClmDiagnosisCode_4                      -0.060753        0.000977
# ClmDiagnosisCode_5                      -0.076127        0.000645
# ClmDiagnosisCode_6                      -0.080205        0.000236
# ClmDiagnosisCode_7                      -0.084575       -0.000524
# ClmDiagnosisCode_8                      -0.085555       -0.000124
# ClmDiagnosisCode_9                      -0.083202        0.001894
# ClmDiagnosisCode_10                     -0.025316        0.000177
# ClmProcedureCode_1                      -0.087635        0.000721
# ClmProcedureCode_2                      -0.039502       -0.000860
# ClmProcedureCode_3                      -0.016357       -0.000992
# ClmProcedureCode_4                      -0.005563       -0.002319
# ClmProcedureCode_5                      -0.002073       -0.001686
# ClmProcedureCode_6                            NaN             NaN
# ChronicCondScore                         1.000000       -0.002091
# BeneID_numeric                          -0.002091        1.000000
# ClaimID_numeric                          0.078748        0.002142
# Provider_numeric                         0.003616       -0.000491
# AttendingPhysician_numeric              -0.002699        0.000692
# OperatingPhysician_numeric              -0.050537        0.001610
# OtherPhysician_numeric                   0.088569        0.001919
# DiagnosisScore                          -0.091113        0.008589
# ProcedureScore                          -0.078318       -0.000118
#
#                                  ClaimID_numeric  Provider_numeric  \
# InscClaimAmtReimbursed                 -0.319491         -0.011600
# Gender                                  0.001018          0.006139
# Race                                    0.001603         -0.053626
# RenalDiseaseIndicator                  -0.029958          0.001927
# State                                   0.001164          0.797883
# County                                  0.003555          0.082726
# ChronicCond_Alzheimer                   0.037915          0.005510
# ChronicCond_Heartfailure                0.048102         -0.000087
# ChronicCond_KidneyDisease               0.064287          0.001793
# ChronicCond_Cancer                      0.020382          0.000562
# ChronicCond_ObstrPulmonary              0.055894          0.001196
# ChronicCond_Depression                  0.025376          0.003146
# ChronicCond_Diabetes                    0.041794          0.002035
# ChronicCond_IschemicHeart               0.042393          0.002597
# ChronicCond_Osteoporasis                0.014969         -0.000302
# ChronicCond_rheumatoidarthritis         0.019566         -0.000473
# ChronicCond_stroke                      0.035551          0.002968
# IPAnnualReimbursementAmt               -0.147086         -0.009511
# IPAnnualDeductibleAmt                  -0.159001         -0.012963
# OPAnnualReimbursementAmt               -0.004016         -0.004297
# OPAnnualDeductibleAmt                  -0.000310         -0.006255
# ClmAdmitDiagnosisCode                  -0.271868         -0.008314
# DeductibleAmtPaid                      -0.474937         -0.017842
# DiagnosisGroupCode                     -0.407544         -0.016121
# ClmDiagnosisCode_1                      0.024530          0.001235
# ClmDiagnosisCode_2                     -0.042734         -0.003758
# ClmDiagnosisCode_3                     -0.079262         -0.002179
# ClmDiagnosisCode_4                     -0.112309         -0.004686
# ClmDiagnosisCode_5                     -0.141075         -0.004513
# ClmDiagnosisCode_6                     -0.158001         -0.006029
# ClmDiagnosisCode_7                     -0.172468         -0.006759
# ClmDiagnosisCode_8                     -0.180646         -0.006181
# ClmDiagnosisCode_9                     -0.185107         -0.009094
# ClmDiagnosisCode_10                    -0.069846         -0.003121
# ClmProcedureCode_1                     -0.358968         -0.012915
# ClmProcedureCode_2                     -0.172454         -0.008557
# ClmProcedureCode_3                     -0.072600         -0.004422
# ClmProcedureCode_4                     -0.025223          0.000270
# ClmProcedureCode_5                     -0.007266          0.000169
# ClmProcedureCode_6                           NaN               NaN
# ChronicCondScore                        0.078748          0.003616
# BeneID_numeric                          0.002142         -0.000491
# ClaimID_numeric                         1.000000          0.010271
# Provider_numeric                        0.010271          1.000000
# AttendingPhysician_numeric             -0.008333          0.006165
# OperatingPhysician_numeric             -0.127884         -0.004170
# OtherPhysician_numeric                  0.203517          0.001203
# DiagnosisScore                         -0.189176         -0.007664
# ProcedureScore                         -0.325680         -0.012788
#
#                                  AttendingPhysician_numeric  \
# InscClaimAmtReimbursed                             0.011736
# Gender                                            -0.000560
# Race                                               0.003283
# RenalDiseaseIndicator                              0.001799
# State                                              0.007712
# County                                             0.007215
# ChronicCond_Alzheimer                             -0.002924
# ChronicCond_Heartfailure                          -0.001390
# ChronicCond_KidneyDisease                         -0.001863
# ChronicCond_Cancer                                -0.000571
# ChronicCond_ObstrPulmonary                        -0.003215
# ChronicCond_Depression                             0.000416
# ChronicCond_Diabetes                              -0.000866
# ChronicCond_IschemicHeart                         -0.000189
# ChronicCond_Osteoporasis                           0.000400
# ChronicCond_rheumatoidarthritis                   -0.002969
# ChronicCond_stroke                                -0.000360
# IPAnnualReimbursementAmt                           0.005629
# IPAnnualDeductibleAmt                              0.005716
# OPAnnualReimbursementAmt                           0.000265
# OPAnnualDeductibleAmt                              0.001397
# ClmAdmitDiagnosisCode                              0.004421
# DeductibleAmtPaid                                  0.015289
# DiagnosisGroupCode                                 0.013850
# ClmDiagnosisCode_1                                -0.001667
# ClmDiagnosisCode_2                                 0.002546
# ClmDiagnosisCode_3                                 0.003239
# ClmDiagnosisCode_4                                 0.001263
# ClmDiagnosisCode_5                                 0.003995
# ClmDiagnosisCode_6                                 0.003395
# ClmDiagnosisCode_7                                 0.004993
# ClmDiagnosisCode_8                                 0.003127
# ClmDiagnosisCode_9                                 0.005820
# ClmDiagnosisCode_10                                0.001549
# ClmProcedureCode_1                                 0.011889
# ClmProcedureCode_2                                 0.007885
# ClmProcedureCode_3                                 0.005362
# ClmProcedureCode_4                                -0.000516
# ClmProcedureCode_5                                 0.000877
# ClmProcedureCode_6                                      NaN
# ChronicCondScore                                  -0.002699
# BeneID_numeric                                     0.000692
# ClaimID_numeric                                   -0.008333
# Provider_numeric                                   0.006165
# AttendingPhysician_numeric                         1.000000
# OperatingPhysician_numeric                         0.028603
# OtherPhysician_numeric                             0.025255
# DiagnosisScore                                     0.004835
# ProcedureScore                                     0.011977
#
#                                  OperatingPhysician_numeric  \
# InscClaimAmtReimbursed                             0.263042
# Gender                                            -0.003421
# Race                                               0.000468
# RenalDiseaseIndicator                              0.039453
# State                                              0.001090
# County                                             0.001243
# ChronicCond_Alzheimer                             -0.012326
# ChronicCond_Heartfailure                          -0.025003
# ChronicCond_KidneyDisease                         -0.049733
# ChronicCond_Cancer                                -0.025524
# ChronicCond_ObstrPulmonary                        -0.030588
# ChronicCond_Depression                            -0.006198
# ChronicCond_Diabetes                              -0.029854
# ChronicCond_IschemicHeart                         -0.036355
# ChronicCond_Osteoporasis                          -0.008077
# ChronicCond_rheumatoidarthritis                   -0.023106
# ChronicCond_stroke                                -0.016640
# IPAnnualReimbursementAmt                           0.114771
# IPAnnualDeductibleAmt                              0.092676
# OPAnnualReimbursementAmt                           0.045769
# OPAnnualDeductibleAmt                              0.049553
# ClmAdmitDiagnosisCode                              0.172802
# DeductibleAmtPaid                                  0.265461
# DiagnosisGroupCode                                 0.235691
# ClmDiagnosisCode_1                                 0.077349
# ClmDiagnosisCode_2                                 0.094810
# ClmDiagnosisCode_3                                 0.131139
# ClmDiagnosisCode_4                                 0.158531
# ClmDiagnosisCode_5                                 0.176013
# ClmDiagnosisCode_6                                 0.180540
# ClmDiagnosisCode_7                                 0.175460
# ClmDiagnosisCode_8                                 0.169189
# ClmDiagnosisCode_9                                 0.158271
# ClmDiagnosisCode_10                                0.068032
# ClmProcedureCode_1                                 0.411311
# ClmProcedureCode_2                                 0.197807
# ClmProcedureCode_3                                 0.083070
# ClmProcedureCode_4                                 0.028444
# ClmProcedureCode_5                                 0.007631
# ClmProcedureCode_6                                      NaN
# ChronicCondScore                                  -0.050537
# BeneID_numeric                                     0.001610
# ClaimID_numeric                                   -0.127884
# Provider_numeric                                  -0.004170
# AttendingPhysician_numeric                         0.028603
# OperatingPhysician_numeric                         1.000000
# OtherPhysician_numeric                             0.025436
# DiagnosisScore                                     0.271401
# ProcedureScore                                     0.373191
#
#                                  OtherPhysician_numeric  DiagnosisScore  \
# InscClaimAmtReimbursed                        -0.086468        0.312982
# Gender                                        -0.003557        0.001080
# Race                                           0.001019       -0.000066
# RenalDiseaseIndicator                         -0.032438        0.029518
# State                                         -0.000706        0.000409
# County                                         0.002947       -0.001105
# ChronicCond_Alzheimer                          0.047340       -0.048813
# ChronicCond_Heartfailure                       0.056238       -0.044294
# ChronicCond_KidneyDisease                      0.059475       -0.065731
# ChronicCond_Cancer                             0.026620       -0.022798
# ChronicCond_ObstrPulmonary                     0.053138       -0.057513
# ChronicCond_Depression                         0.036888       -0.048197
# ChronicCond_Diabetes                           0.049795       -0.047575
# ChronicCond_IschemicHeart                      0.043170       -0.041023
# ChronicCond_Osteoporasis                       0.020322       -0.021725
# ChronicCond_rheumatoidarthritis                0.024887       -0.034309
# ChronicCond_stroke                             0.039024       -0.034579
# IPAnnualReimbursementAmt                      -0.064206        0.141089
# IPAnnualDeductibleAmt                         -0.072786        0.140350
# OPAnnualReimbursementAmt                      -0.009045       -0.008283
# OPAnnualDeductibleAmt                         -0.010344       -0.006639
# ClmAdmitDiagnosisCode                         -0.194779        0.215780
# DeductibleAmtPaid                             -0.143131        0.402489
# DiagnosisGroupCode                            -0.123786        0.377283
# ClmDiagnosisCode_1                             0.022997        0.431565
# ClmDiagnosisCode_2                             0.007782        0.504245
# ClmDiagnosisCode_3                            -0.003103        0.544273
# ClmDiagnosisCode_4                            -0.017255        0.556554
# ClmDiagnosisCode_5                            -0.027222        0.555259
# ClmDiagnosisCode_6                            -0.034019        0.539396
# ClmDiagnosisCode_7                            -0.039585        0.510037
# ClmDiagnosisCode_8                            -0.043475        0.471878
# ClmDiagnosisCode_9                            -0.047586        0.424966
# ClmDiagnosisCode_10                           -0.012220        0.196516
# ClmProcedureCode_1                            -0.096468        0.325739
# ClmProcedureCode_2                            -0.039502        0.158751
# ClmProcedureCode_3                            -0.016734        0.066816
# ClmProcedureCode_4                            -0.006530        0.025125
# ClmProcedureCode_5                            -0.002203        0.006687
# ClmProcedureCode_6                                  NaN             NaN
# ChronicCondScore                               0.088569       -0.091113
# BeneID_numeric                                 0.001919        0.008589
# ClaimID_numeric                                0.203517       -0.189176
# Provider_numeric                               0.001203       -0.007664
# AttendingPhysician_numeric                     0.025255        0.004835
# OperatingPhysician_numeric                     0.025436        0.271401
# OtherPhysician_numeric                         1.000000       -0.025335
# DiagnosisScore                                -0.025335        1.000000
# ProcedureScore                                -0.084578        0.296627
#
#                                  ProcedureScore
# InscClaimAmtReimbursed                 0.631297
# Gender                                -0.001518
# Race                                  -0.002061
# RenalDiseaseIndicator                  0.036706
# State                                 -0.001357
# County                                -0.001337
# ChronicCond_Alzheimer                 -0.027790
# ChronicCond_Heartfailure              -0.047807
# ChronicCond_KidneyDisease             -0.074233
# ChronicCond_Cancer                    -0.027888
# ChronicCond_ObstrPulmonary            -0.058756
# ChronicCond_Depression                -0.015404
# ChronicCond_Diabetes                  -0.039263
# ChronicCond_IschemicHeart             -0.049065
# ChronicCond_Osteoporasis              -0.009520
# ChronicCond_rheumatoidarthritis       -0.021545
# ChronicCond_stroke                    -0.035767
# IPAnnualReimbursementAmt               0.262235
# IPAnnualDeductibleAmt                  0.211462
# OPAnnualReimbursementAmt              -0.002388
# OPAnnualDeductibleAmt                 -0.008564
# ClmAdmitDiagnosisCode                  0.293535
# DeductibleAmtPaid                      0.665439
# DiagnosisGroupCode                     0.572119
# ClmDiagnosisCode_1                    -0.017837
# ClmDiagnosisCode_2                     0.071533
# ClmDiagnosisCode_3                     0.120828
# ClmDiagnosisCode_4                     0.169584
# ClmDiagnosisCode_5                     0.210561
# ClmDiagnosisCode_6                     0.238386
# ClmDiagnosisCode_7                     0.263059
# ClmDiagnosisCode_8                     0.274332
# ClmDiagnosisCode_9                     0.281880
# ClmDiagnosisCode_10                    0.132222
# ClmProcedureCode_1                     0.907090
# ClmProcedureCode_2                     0.773811
# ClmProcedureCode_3                     0.469103
# ClmProcedureCode_4                     0.214782
# ClmProcedureCode_5                     0.073939
# ClmProcedureCode_6                          NaN
# ChronicCondScore                      -0.078318
# BeneID_numeric                        -0.000118
# ClaimID_numeric                       -0.325680
# Provider_numeric                      -0.012788
# AttendingPhysician_numeric             0.011977
# OperatingPhysician_numeric             0.373191
# OtherPhysician_numeric                -0.084578
# DiagnosisScore                         0.296627
# ProcedureScore                         1.000000
#
# [49 rows x 49 columns]

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
columns_to_drop=['ClaimID_numeric','ClmDiagnosisCode_1','ClmDiagnosisCode_2','ClmDiagnosisCode_3','ClmDiagnosisCode_4','ClmDiagnosisCode_5','ClmDiagnosisCode_6','ClmDiagnosisCode_7','ClmDiagnosisCode_8','ClmDiagnosisCode_9','ClmDiagnosisCode_10','ClmProcedureCode_1','ClmProcedureCode_2','ClmProcedureCode_3','ClmProcedureCode_4','ClmProcedureCode_5','ClmProcedureCode_6','ChronicCond_Alzheimer','ChronicCond_Heartfailure','ChronicCond_KidneyDisease','ChronicCond_Cancer','ChronicCond_ObstrPulmonary','ChronicCond_Depression','ChronicCond_Diabetes','ChronicCond_IschemicHeart','ChronicCond_Osteoporasis','ChronicCond_rheumatoidarthritis','ChronicCond_stroke']
final_train = final_train.drop(columns=columns_to_drop)
final_test = final_test.drop(columns=columns_to_drop)

# %%
final_train = final_train.drop('OtherPhysician_numeric',axis=1)
final_test = final_test.drop('OtherPhysician_numeric',axis=1)

# %%
final_train
# Out:
#         Gender  Race  RenalDiseaseIndicator  State  County  \
# 0            1     1                      0     39     230
# 1            1     1                      0     39     230
# 2            1     1                      0     39     230
# 3            2     1                      0     39     280
# 4            1     1                      0     52     590
# ...        ...   ...                    ...    ...     ...
# 558206       2     1                      0     21      20
# 558207       2     1                      0     21      20
# 558208       2     1                      0     21      20
# 558209       2     1                      0     21      20
# 558210       2     1                      0     21      20
#
#         IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                          36000                   3204
# 1                          36000                   3204
# 2                          36000                   3204
# 3                              0                      0
# 4                              0                      0
# ...                          ...                    ...
# 558206                         0                      0
# 558207                         0                      0
# 558208                         0                      0
# 558209                         0                      0
# 558210                         0                      0
#
#         OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  \
# 0                             60                     70
# 1                             60                     70
# 2                             60                     70
# 3                             30                     50
# 4                             90                     40
# ...                          ...                    ...
# 558206                      5470                   1870
# 558207                      5470                   1870
# 558208                      5470                   1870
# 558209                      5470                   1870
# 558210                      5470                   1870
#
#         InscClaimAmtReimbursed  ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0                        26000                   7866             1068.0
# 1                         5000                   6186             1068.0
# 2                         5000                  29590             1068.0
# 3                           30                  56409                0.0
# 4                           80                  79380                0.0
# ...                        ...                    ...                ...
# 558206                     800                      0                0.0
# 558207                     400                      0                0.0
# 558208                      60                      0                0.0
# 558209                      70                      0                0.0
# 558210                      80                      0                0.0
#
#         DiagnosisGroupCode  ChronicCondScore  BeneID_numeric  \
# 0                      201                15           11001
# 1                      750                15           11001
# 2                      883                15           11001
# 3                        0                22           11002
# 4                        0                20           11003
# ...                    ...               ...             ...
# 558206                   0                17          159198
# 558207                   0                17          159198
# 558208                   0                17          159198
# 558209                   0                17          159198
# 558210                   0                17          159198
#
#         Provider_numeric  AttendingPhysician_numeric  \
# 0                  55912                      390922
# 1                  55907                      318495
# 2                  56046                      372395
# 3                  56011                      326117
# 4                  57610                      362868
# ...                  ...                         ...
# 558206             53699                      364188
# 558207             53702                      423019
# 558208             53676                      361063
# 558209             53689                      403198
# 558210             53689                      419379
#
#         OperatingPhysician_numeric  DiagnosisScore  ProcedureScore
# 0                                0           10772               0
# 1                           318495            1219           10962
# 2                                0            8865               0
# 3                                0            2169               0
# 4                                0               5               0
# ...                            ...             ...             ...
# 558206                      364188           12113               0
# 558207                      332284           10438               0
# 558208                           0             630               0
# 558209                           0               0               0
# 558210                           0           13375               0
#
# [536728 rows x 20 columns]

# %%
final_test
# Out:
#         Gender  Race  RenalDiseaseIndicator  State  County  \
# 0            1     1                      0     39     230
# 1            1     1                      0     39     230
# 2            1     2                      0     45     610
# 3            1     2                      0     45     610
# 4            1     2                      0     45     610
# ...        ...   ...                    ...    ...     ...
# 135387       2     1                      0     36     170
# 135388       2     1                      0     36     170
# 135389       1     1                      0     39     140
# 135390       2     1                      0      6     150
# 135391       1     1                      0     16     560
#
#         IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                          36000                   3204
# 1                          36000                   3204
# 2                              0                      0
# 3                              0                      0
# 4                              0                      0
# ...                          ...                    ...
# 135387                         0                      0
# 135388                         0                      0
# 135389                         0                      0
# 135390                      2000                   1068
# 135391                         0                      0
#
#         OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  \
# 0                             60                     70
# 1                             60                     70
# 2                           1490                    160
# 3                           1490                    160
# 4                           1490                    160
# ...                          ...                    ...
# 135387                       110                     50
# 135388                       110                     50
# 135389                       430                    460
# 135390                      3240                   1390
# 135391                      2650                     10
#
#         InscClaimAmtReimbursed  ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0                           30                      0                0.0
# 1                           30                      0                0.0
# 2                          200                      0                0.0
# 3                           10                   5939                0.0
# 4                           10                      0                0.0
# ...                        ...                    ...                ...
# 135387                      10                      0                0.0
# 135388                      30                  92420                0.0
# 135389                      30                      0                0.0
# 135390                    2000                  78659             1068.0
# 135391                    2500                      0                0.0
#
#         DiagnosisGroupCode  ChronicCondScore  BeneID_numeric  \
# 0                        0                15           11001
# 1                        0                15           11001
# 2                        0                17           11007
# 3                        0                17           11007
# 4                        0                17           11007
# ...                    ...               ...             ...
# 135387                   0                22          159193
# 135388                   0                22          159193
# 135389                   0                21          159194
# 135390                 294                16          159196
# 135391                   0                19          159197
#
#         Provider_numeric  AttendingPhysician_numeric  \
# 0                  55962                      347633
# 1                  56112                      381777
# 2                  56979                      425311
# 3                  56573                      393253
# 4                  56573                      417685
# ...                  ...                         ...
# 135387             55485                      369098
# 135388             55485                      431298
# 135389             55889                      406767
# 135390             51854                      377087
# 135391             52983                      354437
#
#         OperatingPhysician_numeric  DiagnosisScore  ProcedureScore
# 0                                0            2470               0
# 1                                0            8334               0
# 2                                0               3               0
# 3                           347995             293               0
# 4                                0               5               0
# ...                            ...             ...             ...
# 135387                           0           13819               0
# 135388                           0            3429               0
# 135389                           0            4009               0
# 135390                           0           10710               0
# 135391                           0               0               0
#
# [130193 rows x 20 columns]

# %%
correlation_matrix = final_train.corr()  
correlation_matrix
# Out:
#                               Gender      Race  RenalDiseaseIndicator  \
# Gender                      1.000000  0.002115               0.003338
# Race                        0.002115  1.000000              -0.000352
# RenalDiseaseIndicator       0.003338 -0.000352               1.000000
# State                       0.007816 -0.055540               0.000712
# County                      0.004311 -0.005961               0.010106
# IPAnnualReimbursementAmt    0.000103 -0.000724               0.191448
# IPAnnualDeductibleAmt      -0.001780 -0.001995               0.174073
# OPAnnualReimbursementAmt    0.008082  0.011917               0.342626
# OPAnnualDeductibleAmt       0.005845  0.007563               0.344546
# InscClaimAmtReimbursed     -0.001899 -0.000560               0.060881
# ClmAdmitDiagnosisCode      -0.000925 -0.001250               0.028416
# DeductibleAmtPaid          -0.002281 -0.002301               0.041572
# DiagnosisGroupCode         -0.000949 -0.002302               0.039209
# ChronicCondScore           -0.011652 -0.000719              -0.308998
# BeneID_numeric              0.001444  0.003942               0.004962
# Provider_numeric            0.006139 -0.053626               0.001927
# AttendingPhysician_numeric -0.000560  0.003283               0.001799
# OperatingPhysician_numeric -0.003421  0.000468               0.039453
# DiagnosisScore              0.001080 -0.000066               0.029518
# ProcedureScore             -0.001518 -0.002061               0.036706
#
#                                State    County  IPAnnualReimbursementAmt  \
# Gender                      0.007816  0.004311                  0.000103
# Race                       -0.055540 -0.005961                 -0.000724
# RenalDiseaseIndicator       0.000712  0.010106                  0.191448
# State                       1.000000  0.119705                 -0.005777
# County                      0.119705  1.000000                  0.001340
# IPAnnualReimbursementAmt   -0.005777  0.001340                  1.000000
# IPAnnualDeductibleAmt      -0.009271  0.002522                  0.641507
# OPAnnualReimbursementAmt   -0.008000  0.007164                  0.179954
# OPAnnualDeductibleAmt      -0.009549  0.006851                  0.164482
# InscClaimAmtReimbursed     -0.000099 -0.002042                  0.383292
# ClmAdmitDiagnosisCode      -0.000108  0.000969                  0.134415
# DeductibleAmtPaid          -0.000897 -0.001851                  0.277929
# DiagnosisGroupCode         -0.001705 -0.002057                  0.248107
# ChronicCondScore            0.003498 -0.016672                 -0.311607
# BeneID_numeric             -0.001161 -0.004629                 -0.001007
# Provider_numeric            0.797883  0.082726                 -0.009511
# AttendingPhysician_numeric  0.007712  0.007215                  0.005629
# OperatingPhysician_numeric  0.001090  0.001243                  0.114771
# DiagnosisScore              0.000409 -0.001105                  0.141089
# ProcedureScore             -0.001357 -0.001337                  0.262235
#
#                             IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# Gender                                  -0.001780                  0.008082
# Race                                    -0.001995                  0.011917
# RenalDiseaseIndicator                    0.174073                  0.342626
# State                                   -0.009271                 -0.008000
# County                                   0.002522                  0.007164
# IPAnnualReimbursementAmt                 0.641507                  0.179954
# IPAnnualDeductibleAmt                    1.000000                  0.138655
# OPAnnualReimbursementAmt                 0.138655                  1.000000
# OPAnnualDeductibleAmt                    0.137442                  0.839247
# InscClaimAmtReimbursed                   0.224201                  0.066697
# ClmAdmitDiagnosisCode                    0.145238                 -0.015940
# DeductibleAmtPaid                        0.307789                 -0.028468
# DiagnosisGroupCode                       0.269079                 -0.020936
# ChronicCondScore                        -0.339227                 -0.219460
# BeneID_numeric                          -0.000281                  0.010636
# Provider_numeric                        -0.012963                 -0.004297
# AttendingPhysician_numeric               0.005716                  0.000265
# OperatingPhysician_numeric               0.092676                  0.045769
# DiagnosisScore                           0.140350                 -0.008283
# ProcedureScore                           0.211462                 -0.002388
#
#                             OPAnnualDeductibleAmt  InscClaimAmtReimbursed  \
# Gender                                   0.005845               -0.001899
# Race                                     0.007563               -0.000560
# RenalDiseaseIndicator                    0.344546                0.060881
# State                                   -0.009549               -0.000099
# County                                   0.006851               -0.002042
# IPAnnualReimbursementAmt                 0.164482                0.383292
# IPAnnualDeductibleAmt                    0.137442                0.224201
# OPAnnualReimbursementAmt                 0.839247                0.066697
# OPAnnualDeductibleAmt                    1.000000                0.032241
# InscClaimAmtReimbursed                   0.032241                1.000000
# ClmAdmitDiagnosisCode                   -0.014828                0.279438
# DeductibleAmtPaid                       -0.034212                0.648785
# DiagnosisGroupCode                      -0.025553                0.558078
# ChronicCondScore                        -0.230009               -0.091846
# BeneID_numeric                           0.008093               -0.000552
# Provider_numeric                        -0.006255               -0.011600
# AttendingPhysician_numeric               0.001397                0.011736
# OperatingPhysician_numeric               0.049553                0.263042
# DiagnosisScore                          -0.006639                0.312982
# ProcedureScore                          -0.008564                0.631297
#
#                             ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# Gender                                  -0.000925          -0.002281
# Race                                    -0.001250          -0.002301
# RenalDiseaseIndicator                    0.028416           0.041572
# State                                   -0.000108          -0.000897
# County                                   0.000969          -0.001851
# IPAnnualReimbursementAmt                 0.134415           0.277929
# IPAnnualDeductibleAmt                    0.145238           0.307789
# OPAnnualReimbursementAmt                -0.015940          -0.028468
# OPAnnualDeductibleAmt                   -0.014828          -0.034212
# InscClaimAmtReimbursed                   0.279438           0.648785
# ClmAdmitDiagnosisCode                    1.000000           0.412238
# DeductibleAmtPaid                        0.412238           1.000000
# DiagnosisGroupCode                       0.344439           0.833788
# ChronicCondScore                        -0.092628          -0.121020
# BeneID_numeric                           0.001203          -0.000288
# Provider_numeric                        -0.008314          -0.017842
# AttendingPhysician_numeric               0.004421           0.015289
# OperatingPhysician_numeric               0.172802           0.265461
# DiagnosisScore                           0.215780           0.402489
# ProcedureScore                           0.293535           0.665439
#
#                             DiagnosisGroupCode  ChronicCondScore  \
# Gender                               -0.000949         -0.011652
# Race                                 -0.002302         -0.000719
# RenalDiseaseIndicator                 0.039209         -0.308998
# State                                -0.001705          0.003498
# County                               -0.002057         -0.016672
# IPAnnualReimbursementAmt              0.248107         -0.311607
# IPAnnualDeductibleAmt                 0.269079         -0.339227
# OPAnnualReimbursementAmt             -0.020936         -0.219460
# OPAnnualDeductibleAmt                -0.025553         -0.230009
# InscClaimAmtReimbursed                0.558078         -0.091846
# ClmAdmitDiagnosisCode                 0.344439         -0.092628
# DeductibleAmtPaid                     0.833788         -0.121020
# DiagnosisGroupCode                    1.000000         -0.102077
# ChronicCondScore                     -0.102077          1.000000
# BeneID_numeric                        0.000238         -0.002091
# Provider_numeric                     -0.016121          0.003616
# AttendingPhysician_numeric            0.013850         -0.002699
# OperatingPhysician_numeric            0.235691         -0.050537
# DiagnosisScore                        0.377283         -0.091113
# ProcedureScore                        0.572119         -0.078318
#
#                             BeneID_numeric  Provider_numeric  \
# Gender                            0.001444          0.006139
# Race                              0.003942         -0.053626
# RenalDiseaseIndicator             0.004962          0.001927
# State                            -0.001161          0.797883
# County                           -0.004629          0.082726
# IPAnnualReimbursementAmt         -0.001007         -0.009511
# IPAnnualDeductibleAmt            -0.000281         -0.012963
# OPAnnualReimbursementAmt          0.010636         -0.004297
# OPAnnualDeductibleAmt             0.008093         -0.006255
# InscClaimAmtReimbursed           -0.000552         -0.011600
# ClmAdmitDiagnosisCode             0.001203         -0.008314
# DeductibleAmtPaid                -0.000288         -0.017842
# DiagnosisGroupCode                0.000238         -0.016121
# ChronicCondScore                 -0.002091          0.003616
# BeneID_numeric                    1.000000         -0.000491
# Provider_numeric                 -0.000491          1.000000
# AttendingPhysician_numeric        0.000692          0.006165
# OperatingPhysician_numeric        0.001610         -0.004170
# DiagnosisScore                    0.008589         -0.007664
# ProcedureScore                   -0.000118         -0.012788
#
#                             AttendingPhysician_numeric  \
# Gender                                       -0.000560
# Race                                          0.003283
# RenalDiseaseIndicator                         0.001799
# State                                         0.007712
# County                                        0.007215
# IPAnnualReimbursementAmt                      0.005629
# IPAnnualDeductibleAmt                         0.005716
# OPAnnualReimbursementAmt                      0.000265
# OPAnnualDeductibleAmt                         0.001397
# InscClaimAmtReimbursed                        0.011736
# ClmAdmitDiagnosisCode                         0.004421
# DeductibleAmtPaid                             0.015289
# DiagnosisGroupCode                            0.013850
# ChronicCondScore                             -0.002699
# BeneID_numeric                                0.000692
# Provider_numeric                              0.006165
# AttendingPhysician_numeric                    1.000000
# OperatingPhysician_numeric                    0.028603
# DiagnosisScore                                0.004835
# ProcedureScore                                0.011977
#
#                             OperatingPhysician_numeric  DiagnosisScore  \
# Gender                                       -0.003421        0.001080
# Race                                          0.000468       -0.000066
# RenalDiseaseIndicator                         0.039453        0.029518
# State                                         0.001090        0.000409
# County                                        0.001243       -0.001105
# IPAnnualReimbursementAmt                      0.114771        0.141089
# IPAnnualDeductibleAmt                         0.092676        0.140350
# OPAnnualReimbursementAmt                      0.045769       -0.008283
# OPAnnualDeductibleAmt                         0.049553       -0.006639
# InscClaimAmtReimbursed                        0.263042        0.312982
# ClmAdmitDiagnosisCode                         0.172802        0.215780
# DeductibleAmtPaid                             0.265461        0.402489
# DiagnosisGroupCode                            0.235691        0.377283
# ChronicCondScore                             -0.050537       -0.091113
# BeneID_numeric                                0.001610        0.008589
# Provider_numeric                             -0.004170       -0.007664
# AttendingPhysician_numeric                    0.028603        0.004835
# OperatingPhysician_numeric                    1.000000        0.271401
# DiagnosisScore                                0.271401        1.000000
# ProcedureScore                                0.373191        0.296627
#
#                             ProcedureScore
# Gender                           -0.001518
# Race                             -0.002061
# RenalDiseaseIndicator             0.036706
# State                            -0.001357
# County                           -0.001337
# IPAnnualReimbursementAmt          0.262235
# IPAnnualDeductibleAmt             0.211462
# OPAnnualReimbursementAmt         -0.002388
# OPAnnualDeductibleAmt            -0.008564
# InscClaimAmtReimbursed            0.631297
# ClmAdmitDiagnosisCode             0.293535
# DeductibleAmtPaid                 0.665439
# DiagnosisGroupCode                0.572119
# ChronicCondScore                 -0.078318
# BeneID_numeric                   -0.000118
# Provider_numeric                 -0.012788
# AttendingPhysician_numeric        0.011977
# OperatingPhysician_numeric        0.373191
# DiagnosisScore                    0.296627
# ProcedureScore                    1.000000

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
# from sklearn.metrics import mean_absolute_error, mean_squared_error, median_absolute_error, r2_score, explained_variance_score

# # Mean Absolute Error (MAE)
# mae = mean_absolute_error(y_test, y_pred)
# print(f'Mean Absolute Error (MAE): {mae}')

# # Root Mean Squared Error (RMSE)
# rmse = mean_squared_error(y_test, y_pred, squared=False)
# print(f'Root Mean Squared Error (RMSE): {rmse}')

# # Median Absolute Error (MedAE)
# medae = median_absolute_error(y_test, y_pred)
# print(f'Median Absolute Error (MedAE): {medae}')

# # R-squared (R2) Score
# r2 = r2_score(y_test, y_pred)
# print(f'R-squared (R2) Score: {r2}')

# # Explained Variance Score
# explained_var = explained_variance_score(y_test, y_pred)
# print(f'Explained Variance Score: {explained_var}')

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score

X_train = final_train.drop('InscClaimAmtReimbursed', axis=1)
y_train = final_train['InscClaimAmtReimbursed']

X_test = final_test.drop('InscClaimAmtReimbursed', axis=1)
y_test = final_test['InscClaimAmtReimbursed']


xgb = XGBRegressor()
xgb.fit(X_train, y_train)

y_pred = xgb.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("R^2 Score:", r2)
# Out:
# R^2 Score: 0.79182488237833

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

model = RandomForestRegressor()
# Fit the model
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Calculate RMSE
rmse = mean_squared_error(y_test, y_pred, squared=False)
print(f"RMSE: {rmse}")
r2_random = r2_score(y_test, y_pred)

print("R^2 Score:", r2_random)
# Out:
# RMSE: 1632.3729788155558
# R^2 Score: 0.8114326094857232

# %%
from sklearn.linear_model import LinearRegression

# Initialize the LinearRegression
model = LinearRegression()

# Fit the model
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Calculate RMSE
rmse = mean_squared_error(y_test, y_pred, squared=False)
print(f"RMSE: {rmse}")
r2_lin = r2_score(y_test, y_pred)

print("R^2 Score:", r2_lin)
# Out:
# RMSE: 2545.950658098839
# R^2 Score: 0.5413010331863617

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

model = GradientBoostingRegressor()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2_grad = r2_score(y_test, y_pred)

print("MSE:", mse)
print("R^2 Score:", r2_grad)
# Out:
# MSE: 3377413.108246419
# R^2 Score: 0.7609922511226141

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression(max_iter=1000)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# %%
pip install catboost

# %%
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error, r2_score

catboost_model = CatBoostRegressor(iterations=1000,  learning_rate=0.1,  depth=6)  

catboost_model.fit(X_train, y_train, verbose=False)  

y_pred = catboost_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("R^2 Score:", r2)
# Out:
# MSE: 2564869.249825089
# R^2 Score: 0.8184931467019115

# %%
#Race-1,2,3,5
#State-1-54
#County-0-999(diff of 10 places)

# %%
# Assuming you have already trained the XGBRegressor model and obtained the 'xgb' object

def predict_reimbursed_amount(model, input_params):
    # Convert input parameters to DataFrame
    input_df = pd.DataFrame([input_params])
    
    # Predict the reimbursed amount
    predicted_amount = model.predict(input_df)[0]
    
    return predicted_amount

# Example usage:
input_params = {
    'Gender':1,
    'Race':1,
    'RenalDiseaseIndicator':0,
    'State':39,
    'County':230,
    'IPAnnualReimbursementAmt':36000,
    'IPAnnualDeductibleAmt':3204,
    'OPAnnualReimbursementAmt':60,
    'OPAnnualDeductibleAmt':70,
    'ClmAdmitDiagnosisCode': 7866,
    'DeductibleAmtPaid':1068.0,
    'DiagnosisGroupCode': 201,
    'ChronicCondScore':15,
    'AttendingPhysician_numeric': 390922,
    'Provider_numeric': 55912,
    'BeneID_numeric': 11001,
    'AttendingPhysician_numeric':390922,
    'OperatingPhysician_numeric':0,
    'OtherPhysician_numeric':0,
    'DiagnosisScore':10772,
    'ProcedureScore':0
}

predicted_amount = predict_reimbursed_amount(xgb, input_params)
print("Predicted Reimbursed Amount:", predicted_amount)

# %%
import pickle

with open('catboost_model.pkl', 'wb') as f:
    pickle.dump(catboost_model, f)
